# %%
import tensorflow as tf
import os
import numpy as np
import time
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# Paths
input_dir = '/kaggle/input/brain-ct-sinograms-64-augmented-2-0/Datasets/brain_CT_sinograms_64_augmented'
output_dir = '/kaggle/input/brain-ct-sinograms-64-augmented-2-0/Datasets/brain_CT_64_augmented'

# Get sorted file names (to ensure matching)
input_files = sorted(os.listdir(input_dir))
output_files = sorted(os.listdir(output_dir))

# %%
# Initialize lists
x_data = []
y_data = []

# Load images
for in_file, out_file in zip(input_files, output_files):
    # Load grayscale image and resize to (256, 256)
    input_img = load_img(os.path.join(input_dir, in_file), color_mode='grayscale', target_size=(91,64))
    output_img = load_img(os.path.join(output_dir, out_file), color_mode='grayscale', target_size=(64, 64))
    
    # Convert to array and normalize to [0, 1]
    x = img_to_array(input_img) / 255.0
    y = img_to_array(output_img) / 255.0

    x_data.append(x)
    y_data.append(y)

# Convert to NumPy arrays
x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

print("Input shape:", x_data.shape)   # (125, 256, 256, 1)
print("Output shape:", y_data.shape)  # (125, 256, 256, 1)
# Out:
# Input shape: (2500, 91, 64, 1)
# Output shape: (2500, 64, 64, 1)

# %%
x_train = x_data[:2000]
x_test = x_data[2000:]
y_train = y_data[:2000]
y_test = y_data[2000:]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (2000, 91, 64, 1)
# (2000, 64, 64, 1)

# %%
index = 4

import matplotlib.pyplot as plt
plt.subplot(1, 2, 1)
plt.imshow(x_data[index].squeeze(), cmap='gray')
plt.title('Input (Sinogram)')

plt.subplot(1, 2, 2)
plt.imshow(y_data[index].squeeze(), cmap='gray')
plt.title('Output (CT Image)')
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Mean

def psnr_metric(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim_metric(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
from tensorflow.keras import models, layers
def build_automap(input_shape=(91, 64, 1), dropout_rate=0.3):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Resizing(64, 64),
        layers.Flatten(),
        layers.Dense(4096, activation='relu'),
        layers.Dense(4096, activation='relu'),
        layers.Dense(4096, activation='relu'),
        layers.Dense(4096, activation='tanh'),
        layers.Reshape((64, 64, 1))  # 👈 This fixes the shape
    ])
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
model = build_automap()
model.compile(optimizer=Adam(learning_rate=1e-4), loss=MeanSquaredError(), metrics=[psnr_metric, ssim_metric])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resizing_1 (Resizing)                │ (None, 64, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_1 (Reshape)                  │ (None, 64, 64, 1)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 67,125,248 (256.06 MB)
#  Trainable params: 67,125,248 (256.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# # Training
# history = model.fit(
#     x_train, y_train,
#     validation_data=(x_test, y_test),
#     batch_size=10,
#     epochs= ,
#     verbose=1
# )

# %%
import matplotlib.pyplot as plt

# Assuming you already have:
# model = build_automap(...)
# and your data: x_train, y_train, x_val, y_val

history = model.fit(
    x_train, y_train,
    epochs=300,
    batch_size=8,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/300
# W0000 00:00:1751392894.465017      96 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1751392894.465116      96 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 0.0546 - psnr_metric: 13.0148 - ssim_metric: 0.1193 - val_loss: 0.0333 - val_psnr_metric: 14.8648 - val_ssim_metric: 0.1986
# Epoch 2/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0325 - psnr_metric: 15.0330 - ssim_metric: 0.2186 - val_loss: 0.0299 - val_psnr_metric: 15.3732 - val_ssim_metric: 0.2400
# Epoch 3/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0289 - psnr_metric: 15.5916 - ssim_metric: 0.2587 - val_loss: 0.0288 - val_psnr_metric: 15.5502 - val_ssim_metric: 0.2555
# Epoch 4/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0267 - psnr_metric: 15.9495 - ssim_metric: 0.2842 - val_loss: 0.0274 - val_psnr_metric: 15.7946 - val_ssim_metric: 0.2423
# Epoch 5/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0247 - psnr_metric: 16.2992 - ssim_metric: 0.3039 - val_loss: 0.0255 - val_psnr_metric: 16.1371 - val_ssim_metric: 0.2872
# Epoch 6/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0231 - psnr_metric: 16.6079 - ssim_metric: 0.3293 - val_loss: 0.0249 - val_psnr_metric: 16.2446 - val_ssim_metric: 0.2960
# Epoch 7/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0217 - psnr_metric: 16.9004 - ssim_metric: 0.3452 - val_loss: 0.0243 - val_psnr_metric: 16.3735 - val_ssim_metric: 0.3049
# Epoch 8/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0200 - psnr_metric: 17.2847 - ssim_metric: 0.3679 - val_loss: 0.0240 - val_psnr_metric: 16.4333 - val_ssim_metric: 0.3070
# Epoch 9/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0193 - psnr_metric: 17.4359 - ssim_metric: 0.3812 - val_loss: 0.0240 - val_psnr_metric: 16.4238 - val_ssim_metric: 0.3119
# Epoch 10/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0185 - psnr_metric: 17.6431 - ssim_metric: 0.3934 - val_loss: 0.0234 - val_psnr_metric: 16.5631 - val_ssim_metric: 0.3064
# Epoch 11/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0172 - psnr_metric: 18.0003 - ssim_metric: 0.4150 - val_loss: 0.0230 - val_psnr_metric: 16.6074 - val_ssim_metric: 0.3154
# Epoch 12/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0165 - psnr_metric: 18.1785 - ssim_metric: 0.4270 - val_loss: 0.0229 - val_psnr_metric: 16.6453 - val_ssim_metric: 0.3210
# Epoch 13/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0158 - psnr_metric: 18.3792 - ssim_metric: 0.4392 - val_loss: 0.0229 - val_psnr_metric: 16.6217 - val_ssim_metric: 0.3205
# Epoch 14/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0155 - psnr_metric: 18.4619 - ssim_metric: 0.4520 - val_loss: 0.0228 - val_psnr_metric: 16.6523 - val_ssim_metric: 0.3235
# Epoch 15/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0146 - psnr_metric: 18.7163 - ssim_metric: 0.4644 - val_loss: 0.0227 - val_psnr_metric: 16.6839 - val_ssim_metric: 0.3195
# Epoch 16/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0138 - psnr_metric: 19.0136 - ssim_metric: 0.4777 - val_loss: 0.0223 - val_psnr_metric: 16.7664 - val_ssim_metric: 0.3212
# Epoch 17/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0134 - psnr_metric: 19.1192 - ssim_metric: 0.4884 - val_loss: 0.0224 - val_psnr_metric: 16.7140 - val_ssim_metric: 0.3248
# Epoch 18/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0129 - psnr_metric: 19.2935 - ssim_metric: 0.4978 - val_loss: 0.0223 - val_psnr_metric: 16.7555 - val_ssim_metric: 0.3219
# Epoch 19/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0127 - psnr_metric: 19.3564 - ssim_metric: 0.5038 - val_loss: 0.0222 - val_psnr_metric: 16.7673 - val_ssim_metric: 0.3302
# Epoch 20/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0121 - psnr_metric: 19.5801 - ssim_metric: 0.5196 - val_loss: 0.0223 - val_psnr_metric: 16.7542 - val_ssim_metric: 0.3232
# Epoch 21/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0118 - psnr_metric: 19.6582 - ssim_metric: 0.5278 - val_loss: 0.0222 - val_psnr_metric: 16.7931 - val_ssim_metric: 0.3257
# Epoch 22/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0113 - psnr_metric: 19.8747 - ssim_metric: 0.5344 - val_loss: 0.0223 - val_psnr_metric: 16.7540 - val_ssim_metric: 0.3273
# Epoch 23/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0109 - psnr_metric: 20.0489 - ssim_metric: 0.5446 - val_loss: 0.0224 - val_psnr_metric: 16.7487 - val_ssim_metric: 0.3254
# Epoch 24/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0106 - psnr_metric: 20.1802 - ssim_metric: 0.5488 - val_loss: 0.0227 - val_psnr_metric: 16.6813 - val_ssim_metric: 0.3187
# Epoch 25/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0103 - psnr_metric: 20.3066 - ssim_metric: 0.5536 - val_loss: 0.0226 - val_psnr_metric: 16.6916 - val_ssim_metric: 0.3235
# Epoch 26/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0100 - psnr_metric: 20.4051 - ssim_metric: 0.5599 - val_loss: 0.0228 - val_psnr_metric: 16.6715 - val_ssim_metric: 0.3234
# Epoch 27/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0098 - psnr_metric: 20.5017 - ssim_metric: 0.5676 - val_loss: 0.0226 - val_psnr_metric: 16.7038 - val_ssim_metric: 0.3191
# Epoch 28/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0094 - psnr_metric: 20.6882 - ssim_metric: 0.5765 - val_loss: 0.0229 - val_psnr_metric: 16.6626 - val_ssim_metric: 0.3211
# Epoch 29/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0093 - psnr_metric: 20.7449 - ssim_metric: 0.5834 - val_loss: 0.0226 - val_psnr_metric: 16.7312 - val_ssim_metric: 0.3241
# Epoch 30/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0090 - psnr_metric: 20.8742 - ssim_metric: 0.5857 - val_loss: 0.0228 - val_psnr_metric: 16.6743 - val_ssim_metric: 0.3220
# Epoch 31/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0087 - psnr_metric: 21.0219 - ssim_metric: 0.5949 - val_loss: 0.0230 - val_psnr_metric: 16.6316 - val_ssim_metric: 0.3212
# Epoch 32/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0085 - psnr_metric: 21.1068 - ssim_metric: 0.6007 - val_loss: 0.0228 - val_psnr_metric: 16.6755 - val_ssim_metric: 0.3207
# Epoch 33/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0083 - psnr_metric: 21.2317 - ssim_metric: 0.6032 - val_loss: 0.0231 - val_psnr_metric: 16.6332 - val_ssim_metric: 0.3240
# Epoch 34/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0079 - psnr_metric: 21.4468 - ssim_metric: 0.6137 - val_loss: 0.0230 - val_psnr_metric: 16.6486 - val_ssim_metric: 0.3216
# Epoch 35/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0080 - psnr_metric: 21.3923 - ssim_metric: 0.6096 - val_loss: 0.0231 - val_psnr_metric: 16.6294 - val_ssim_metric: 0.3212
# Epoch 36/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0076 - psnr_metric: 21.6118 - ssim_metric: 0.6220 - val_loss: 0.0232 - val_psnr_metric: 16.5906 - val_ssim_metric: 0.3186
# Epoch 37/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0077 - psnr_metric: 21.5093 - ssim_metric: 0.6183 - val_loss: 0.0232 - val_psnr_metric: 16.6072 - val_ssim_metric: 0.3214
# Epoch 38/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0076 - psnr_metric: 21.6122 - ssim_metric: 0.6183 - val_loss: 0.0232 - val_psnr_metric: 16.5975 - val_ssim_metric: 0.3243
# Epoch 39/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0073 - psnr_metric: 21.7925 - ssim_metric: 0.6306 - val_loss: 0.0233 - val_psnr_metric: 16.6022 - val_ssim_metric: 0.3245
# Epoch 40/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0071 - psnr_metric: 21.9267 - ssim_metric: 0.6407 - val_loss: 0.0235 - val_psnr_metric: 16.5433 - val_ssim_metric: 0.3192
# Epoch 41/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0069 - psnr_metric: 22.0146 - ssim_metric: 0.6428 - val_loss: 0.0235 - val_psnr_metric: 16.5630 - val_ssim_metric: 0.3196
# Epoch 42/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0070 - psnr_metric: 21.9745 - ssim_metric: 0.6388 - val_loss: 0.0234 - val_psnr_metric: 16.5732 - val_ssim_metric: 0.3217
# Epoch 43/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0066 - psnr_metric: 22.2208 - ssim_metric: 0.6498 - val_loss: 0.0238 - val_psnr_metric: 16.5125 - val_ssim_metric: 0.3155
# Epoch 44/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0064 - psnr_metric: 22.3289 - ssim_metric: 0.6491 - val_loss: 0.0237 - val_psnr_metric: 16.5336 - val_ssim_metric: 0.3186
# Epoch 45/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0063 - psnr_metric: 22.4064 - ssim_metric: 0.6564 - val_loss: 0.0237 - val_psnr_metric: 16.5285 - val_ssim_metric: 0.3198
# Epoch 46/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0064 - psnr_metric: 22.3661 - ssim_metric: 0.6538 - val_loss: 0.0239 - val_psnr_metric: 16.4918 - val_ssim_metric: 0.3183
# Epoch 47/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0062 - psnr_metric: 22.4469 - ssim_metric: 0.6608 - val_loss: 0.0238 - val_psnr_metric: 16.5160 - val_ssim_metric: 0.3210
# Epoch 48/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0058 - psnr_metric: 22.7460 - ssim_metric: 0.6689 - val_loss: 0.0239 - val_psnr_metric: 16.4968 - val_ssim_metric: 0.3200
# Epoch 49/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0058 - psnr_metric: 22.7479 - ssim_metric: 0.6711 - val_loss: 0.0240 - val_psnr_metric: 16.4776 - val_ssim_metric: 0.3167
# Epoch 50/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0061 - psnr_metric: 22.5706 - ssim_metric: 0.6603 - val_loss: 0.0241 - val_psnr_metric: 16.4453 - val_ssim_metric: 0.3192
# Epoch 51/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0056 - psnr_metric: 22.8977 - ssim_metric: 0.6763 - val_loss: 0.0241 - val_psnr_metric: 16.4481 - val_ssim_metric: 0.3179
# Epoch 52/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0056 - psnr_metric: 22.8951 - ssim_metric: 0.6740 - val_loss: 0.0240 - val_psnr_metric: 16.4679 - val_ssim_metric: 0.3193
# Epoch 53/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0056 - psnr_metric: 22.8904 - ssim_metric: 0.6800 - val_loss: 0.0241 - val_psnr_metric: 16.4496 - val_ssim_metric: 0.3211
# Epoch 54/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0054 - psnr_metric: 23.0762 - ssim_metric: 0.6817 - val_loss: 0.0243 - val_psnr_metric: 16.4258 - val_ssim_metric: 0.3181
# Epoch 55/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0054 - psnr_metric: 23.1012 - ssim_metric: 0.6812 - val_loss: 0.0243 - val_psnr_metric: 16.4274 - val_ssim_metric: 0.3203
# Epoch 56/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0053 - psnr_metric: 23.1811 - ssim_metric: 0.6872 - val_loss: 0.0246 - val_psnr_metric: 16.3678 - val_ssim_metric: 0.3211
# Epoch 57/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0053 - psnr_metric: 23.1113 - ssim_metric: 0.6752 - val_loss: 0.0244 - val_psnr_metric: 16.4118 - val_ssim_metric: 0.3193
# Epoch 58/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0052 - psnr_metric: 23.2545 - ssim_metric: 0.6907 - val_loss: 0.0245 - val_psnr_metric: 16.3856 - val_ssim_metric: 0.3194
# Epoch 59/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0051 - psnr_metric: 23.3415 - ssim_metric: 0.6943 - val_loss: 0.0244 - val_psnr_metric: 16.4017 - val_ssim_metric: 0.3218
# Epoch 60/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0050 - psnr_metric: 23.4396 - ssim_metric: 0.6984 - val_loss: 0.0245 - val_psnr_metric: 16.3833 - val_ssim_metric: 0.3171
# Epoch 61/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0049 - psnr_metric: 23.5300 - ssim_metric: 0.7030 - val_loss: 0.0246 - val_psnr_metric: 16.3648 - val_ssim_metric: 0.3191
# Epoch 62/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0048 - psnr_metric: 23.5160 - ssim_metric: 0.6971 - val_loss: 0.0246 - val_psnr_metric: 16.3731 - val_ssim_metric: 0.3197
# Epoch 63/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0048 - psnr_metric: 23.5936 - ssim_metric: 0.7027 - val_loss: 0.0246 - val_psnr_metric: 16.3745 - val_ssim_metric: 0.3215
# Epoch 64/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0045 - psnr_metric: 23.8447 - ssim_metric: 0.7130 - val_loss: 0.0247 - val_psnr_metric: 16.3602 - val_ssim_metric: 0.3210
# Epoch 65/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0047 - psnr_metric: 23.6848 - ssim_metric: 0.7049 - val_loss: 0.0249 - val_psnr_metric: 16.3186 - val_ssim_metric: 0.3175
# Epoch 66/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0046 - psnr_metric: 23.7383 - ssim_metric: 0.7066 - val_loss: 0.0249 - val_psnr_metric: 16.3231 - val_ssim_metric: 0.3188
# Epoch 67/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0047 - psnr_metric: 23.6993 - ssim_metric: 0.7036 - val_loss: 0.0249 - val_psnr_metric: 16.3143 - val_ssim_metric: 0.3200
# Epoch 68/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0045 - psnr_metric: 23.8745 - ssim_metric: 0.7124 - val_loss: 0.0250 - val_psnr_metric: 16.3017 - val_ssim_metric: 0.3199
# Epoch 69/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0044 - psnr_metric: 24.0131 - ssim_metric: 0.7181 - val_loss: 0.0250 - val_psnr_metric: 16.2979 - val_ssim_metric: 0.3196
# Epoch 70/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0044 - psnr_metric: 23.9991 - ssim_metric: 0.7120 - val_loss: 0.0249 - val_psnr_metric: 16.3137 - val_ssim_metric: 0.3193
# Epoch 71/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0043 - psnr_metric: 24.0731 - ssim_metric: 0.7204 - val_loss: 0.0250 - val_psnr_metric: 16.2863 - val_ssim_metric: 0.3207
# Epoch 72/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0042 - psnr_metric: 24.1636 - ssim_metric: 0.7207 - val_loss: 0.0250 - val_psnr_metric: 16.3059 - val_ssim_metric: 0.3215
# Epoch 73/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0042 - psnr_metric: 24.1421 - ssim_metric: 0.7227 - val_loss: 0.0252 - val_psnr_metric: 16.2599 - val_ssim_metric: 0.3227
# Epoch 74/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0041 - psnr_metric: 24.2327 - ssim_metric: 0.7234 - val_loss: 0.0251 - val_psnr_metric: 16.2847 - val_ssim_metric: 0.3232
# Epoch 75/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0041 - psnr_metric: 24.2414 - ssim_metric: 0.7246 - val_loss: 0.0253 - val_psnr_metric: 16.2466 - val_ssim_metric: 0.3219
# Epoch 76/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0040 - psnr_metric: 24.3778 - ssim_metric: 0.7278 - val_loss: 0.0252 - val_psnr_metric: 16.2650 - val_ssim_metric: 0.3207
# Epoch 77/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0041 - psnr_metric: 24.2740 - ssim_metric: 0.7250 - val_loss: 0.0252 - val_psnr_metric: 16.2573 - val_ssim_metric: 0.3227
# Epoch 78/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0040 - psnr_metric: 24.3201 - ssim_metric: 0.7240 - val_loss: 0.0253 - val_psnr_metric: 16.2611 - val_ssim_metric: 0.3220
# Epoch 79/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0039 - psnr_metric: 24.4654 - ssim_metric: 0.7313 - val_loss: 0.0253 - val_psnr_metric: 16.2437 - val_ssim_metric: 0.3240
# Epoch 80/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0039 - psnr_metric: 24.5398 - ssim_metric: 0.7328 - val_loss: 0.0254 - val_psnr_metric: 16.2322 - val_ssim_metric: 0.3228
# Epoch 81/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0039 - psnr_metric: 24.5103 - ssim_metric: 0.7304 - val_loss: 0.0253 - val_psnr_metric: 16.2538 - val_ssim_metric: 0.3246
# Epoch 82/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0037 - psnr_metric: 24.7159 - ssim_metric: 0.7386 - val_loss: 0.0254 - val_psnr_metric: 16.2410 - val_ssim_metric: 0.3232
# Epoch 83/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0037 - psnr_metric: 24.6905 - ssim_metric: 0.7337 - val_loss: 0.0255 - val_psnr_metric: 16.2234 - val_ssim_metric: 0.3264
# Epoch 84/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0037 - psnr_metric: 24.6667 - ssim_metric: 0.7392 - val_loss: 0.0255 - val_psnr_metric: 16.2381 - val_ssim_metric: 0.3262
# Epoch 85/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0036 - psnr_metric: 24.7953 - ssim_metric: 0.7379 - val_loss: 0.0255 - val_psnr_metric: 16.2086 - val_ssim_metric: 0.3258
# Epoch 86/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0036 - psnr_metric: 24.8010 - ssim_metric: 0.7386 - val_loss: 0.0254 - val_psnr_metric: 16.2395 - val_ssim_metric: 0.3241
# Epoch 87/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0036 - psnr_metric: 24.8640 - ssim_metric: 0.7383 - val_loss: 0.0257 - val_psnr_metric: 16.1974 - val_ssim_metric: 0.3236
# Epoch 88/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0036 - psnr_metric: 24.9062 - ssim_metric: 0.7429 - val_loss: 0.0255 - val_psnr_metric: 16.2281 - val_ssim_metric: 0.3264
# Epoch 89/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0035 - psnr_metric: 24.9996 - ssim_metric: 0.7463 - val_loss: 0.0255 - val_psnr_metric: 16.2202 - val_ssim_metric: 0.3248
# Epoch 90/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0036 - psnr_metric: 24.8658 - ssim_metric: 0.7439 - val_loss: 0.0257 - val_psnr_metric: 16.1939 - val_ssim_metric: 0.3289
# Epoch 91/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0032 - psnr_metric: 25.2984 - ssim_metric: 0.7571 - val_loss: 0.0256 - val_psnr_metric: 16.1917 - val_ssim_metric: 0.3260
# Epoch 92/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0034 - psnr_metric: 25.0591 - ssim_metric: 0.7490 - val_loss: 0.0256 - val_psnr_metric: 16.2074 - val_ssim_metric: 0.3262
# Epoch 93/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0034 - psnr_metric: 25.0842 - ssim_metric: 0.7446 - val_loss: 0.0257 - val_psnr_metric: 16.1769 - val_ssim_metric: 0.3269
# Epoch 94/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0033 - psnr_metric: 25.1630 - ssim_metric: 0.7496 - val_loss: 0.0258 - val_psnr_metric: 16.1619 - val_ssim_metric: 0.3260
# Epoch 95/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0034 - psnr_metric: 25.1239 - ssim_metric: 0.7454 - val_loss: 0.0258 - val_psnr_metric: 16.1768 - val_ssim_metric: 0.3270
# Epoch 96/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0033 - psnr_metric: 25.2031 - ssim_metric: 0.7520 - val_loss: 0.0257 - val_psnr_metric: 16.1851 - val_ssim_metric: 0.3286
# Epoch 97/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0031 - psnr_metric: 25.4173 - ssim_metric: 0.7616 - val_loss: 0.0257 - val_psnr_metric: 16.1852 - val_ssim_metric: 0.3311
# Epoch 98/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0032 - psnr_metric: 25.3919 - ssim_metric: 0.7584 - val_loss: 0.0258 - val_psnr_metric: 16.1825 - val_ssim_metric: 0.3311
# Epoch 99/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0033 - psnr_metric: 25.2417 - ssim_metric: 0.7527 - val_loss: 0.0259 - val_psnr_metric: 16.1525 - val_ssim_metric: 0.3280
# Epoch 100/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0031 - psnr_metric: 25.4526 - ssim_metric: 0.7586 - val_loss: 0.0256 - val_psnr_metric: 16.1958 - val_ssim_metric: 0.3344
# Epoch 101/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0031 - psnr_metric: 25.5058 - ssim_metric: 0.7603 - val_loss: 0.0260 - val_psnr_metric: 16.1428 - val_ssim_metric: 0.3275
# Epoch 102/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0032 - psnr_metric: 25.2856 - ssim_metric: 0.7493 - val_loss: 0.0259 - val_psnr_metric: 16.1470 - val_ssim_metric: 0.3280
# Epoch 103/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0032 - psnr_metric: 25.3371 - ssim_metric: 0.7532 - val_loss: 0.0260 - val_psnr_metric: 16.1340 - val_ssim_metric: 0.3314
# Epoch 104/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0032 - psnr_metric: 25.3293 - ssim_metric: 0.7534 - val_loss: 0.0259 - val_psnr_metric: 16.1518 - val_ssim_metric: 0.3316
# Epoch 105/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.7595 - ssim_metric: 0.7722 - val_loss: 0.0260 - val_psnr_metric: 16.1310 - val_ssim_metric: 0.3322
# Epoch 106/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.7500 - ssim_metric: 0.7696 - val_loss: 0.0260 - val_psnr_metric: 16.1365 - val_ssim_metric: 0.3322
# Epoch 107/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.7267 - ssim_metric: 0.7682 - val_loss: 0.0261 - val_psnr_metric: 16.1185 - val_ssim_metric: 0.3292
# Epoch 108/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.8100 - ssim_metric: 0.7668 - val_loss: 0.0261 - val_psnr_metric: 16.1177 - val_ssim_metric: 0.3331
# Epoch 109/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0030 - psnr_metric: 25.6966 - ssim_metric: 0.7650 - val_loss: 0.0261 - val_psnr_metric: 16.1208 - val_ssim_metric: 0.3319
# Epoch 110/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.7958 - ssim_metric: 0.7693 - val_loss: 0.0260 - val_psnr_metric: 16.1352 - val_ssim_metric: 0.3360
# Epoch 111/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.7955 - ssim_metric: 0.7673 - val_loss: 0.0261 - val_psnr_metric: 16.1160 - val_ssim_metric: 0.3306
# Epoch 112/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0029 - psnr_metric: 25.7484 - ssim_metric: 0.7653 - val_loss: 0.0261 - val_psnr_metric: 16.1095 - val_ssim_metric: 0.3329
# Epoch 113/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0028 - psnr_metric: 25.9639 - ssim_metric: 0.7728 - val_loss: 0.0263 - val_psnr_metric: 16.0943 - val_ssim_metric: 0.3315
# Epoch 114/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0028 - psnr_metric: 26.0021 - ssim_metric: 0.7738 - val_loss: 0.0261 - val_psnr_metric: 16.1160 - val_ssim_metric: 0.3363
# Epoch 115/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0027 - psnr_metric: 26.0710 - ssim_metric: 0.7767 - val_loss: 0.0262 - val_psnr_metric: 16.1170 - val_ssim_metric: 0.3350
# Epoch 116/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0028 - psnr_metric: 25.8745 - ssim_metric: 0.7726 - val_loss: 0.0260 - val_psnr_metric: 16.1355 - val_ssim_metric: 0.3386
# Epoch 117/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0028 - psnr_metric: 25.9082 - ssim_metric: 0.7731 - val_loss: 0.0261 - val_psnr_metric: 16.1251 - val_ssim_metric: 0.3358
# Epoch 118/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0028 - psnr_metric: 25.9281 - ssim_metric: 0.7723 - val_loss: 0.0263 - val_psnr_metric: 16.0851 - val_ssim_metric: 0.3326
# Epoch 119/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0027 - psnr_metric: 26.1674 - ssim_metric: 0.7803 - val_loss: 0.0262 - val_psnr_metric: 16.1068 - val_ssim_metric: 0.3369
# Epoch 120/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2014 - ssim_metric: 0.7828 - val_loss: 0.0262 - val_psnr_metric: 16.1116 - val_ssim_metric: 0.3367
# Epoch 121/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2515 - ssim_metric: 0.7823 - val_loss: 0.0262 - val_psnr_metric: 16.0952 - val_ssim_metric: 0.3367
# Epoch 122/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2384 - ssim_metric: 0.7821 - val_loss: 0.0262 - val_psnr_metric: 16.1095 - val_ssim_metric: 0.3372
# Epoch 123/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2298 - ssim_metric: 0.7788 - val_loss: 0.0264 - val_psnr_metric: 16.0751 - val_ssim_metric: 0.3330
# Epoch 124/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2050 - ssim_metric: 0.7768 - val_loss: 0.0264 - val_psnr_metric: 16.0710 - val_ssim_metric: 0.3343
# Epoch 125/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0027 - psnr_metric: 26.0592 - ssim_metric: 0.7693 - val_loss: 0.0264 - val_psnr_metric: 16.0704 - val_ssim_metric: 0.3384
# Epoch 126/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0027 - psnr_metric: 26.0670 - ssim_metric: 0.7700 - val_loss: 0.0263 - val_psnr_metric: 16.0923 - val_ssim_metric: 0.3389
# Epoch 127/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0025 - psnr_metric: 26.3594 - ssim_metric: 0.7812 - val_loss: 0.0263 - val_psnr_metric: 16.1013 - val_ssim_metric: 0.3411
# Epoch 128/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0024 - psnr_metric: 26.5836 - ssim_metric: 0.7937 - val_loss: 0.0265 - val_psnr_metric: 16.0570 - val_ssim_metric: 0.3364
# Epoch 129/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0024 - psnr_metric: 26.5193 - ssim_metric: 0.7875 - val_loss: 0.0263 - val_psnr_metric: 16.0904 - val_ssim_metric: 0.3382
# Epoch 130/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2836 - ssim_metric: 0.7809 - val_loss: 0.0265 - val_psnr_metric: 16.0587 - val_ssim_metric: 0.3378
# Epoch 131/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0025 - psnr_metric: 26.4942 - ssim_metric: 0.7865 - val_loss: 0.0264 - val_psnr_metric: 16.0658 - val_ssim_metric: 0.3388
# Epoch 132/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0024 - psnr_metric: 26.5090 - ssim_metric: 0.7885 - val_loss: 0.0267 - val_psnr_metric: 16.0240 - val_ssim_metric: 0.3368
# Epoch 133/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0025 - psnr_metric: 26.4666 - ssim_metric: 0.7849 - val_loss: 0.0263 - val_psnr_metric: 16.0896 - val_ssim_metric: 0.3412
# Epoch 134/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0026 - psnr_metric: 26.2844 - ssim_metric: 0.7805 - val_loss: 0.0266 - val_psnr_metric: 16.0385 - val_ssim_metric: 0.3388
# Epoch 135/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7232 - ssim_metric: 0.7943 - val_loss: 0.0266 - val_psnr_metric: 16.0334 - val_ssim_metric: 0.3383
# Epoch 136/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0024 - psnr_metric: 26.6549 - ssim_metric: 0.7891 - val_loss: 0.0266 - val_psnr_metric: 16.0481 - val_ssim_metric: 0.3419
# Epoch 137/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0024 - psnr_metric: 26.5367 - ssim_metric: 0.7858 - val_loss: 0.0266 - val_psnr_metric: 16.0521 - val_ssim_metric: 0.3394
# Epoch 138/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0025 - psnr_metric: 26.4317 - ssim_metric: 0.7804 - val_loss: 0.0266 - val_psnr_metric: 16.0398 - val_ssim_metric: 0.3389
# Epoch 139/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7468 - ssim_metric: 0.7962 - val_loss: 0.0264 - val_psnr_metric: 16.0745 - val_ssim_metric: 0.3432
# Epoch 140/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.8272 - ssim_metric: 0.7915 - val_loss: 0.0266 - val_psnr_metric: 16.0508 - val_ssim_metric: 0.3410
# Epoch 141/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.8418 - ssim_metric: 0.7954 - val_loss: 0.0266 - val_psnr_metric: 16.0354 - val_ssim_metric: 0.3416
# Epoch 142/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7495 - ssim_metric: 0.7946 - val_loss: 0.0267 - val_psnr_metric: 16.0281 - val_ssim_metric: 0.3424
# Epoch 143/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0024 - psnr_metric: 26.6366 - ssim_metric: 0.7890 - val_loss: 0.0266 - val_psnr_metric: 16.0380 - val_ssim_metric: 0.3441
# Epoch 144/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0022 - psnr_metric: 27.0692 - ssim_metric: 0.8015 - val_loss: 0.0266 - val_psnr_metric: 16.0351 - val_ssim_metric: 0.3432
# Epoch 145/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7663 - ssim_metric: 0.7927 - val_loss: 0.0265 - val_psnr_metric: 16.0371 - val_ssim_metric: 0.3457
# Epoch 146/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0022 - psnr_metric: 26.9540 - ssim_metric: 0.7960 - val_loss: 0.0266 - val_psnr_metric: 16.0338 - val_ssim_metric: 0.3442
# Epoch 147/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7995 - ssim_metric: 0.7934 - val_loss: 0.0266 - val_psnr_metric: 16.0273 - val_ssim_metric: 0.3437
# Epoch 148/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7683 - ssim_metric: 0.7914 - val_loss: 0.0266 - val_psnr_metric: 16.0410 - val_ssim_metric: 0.3468
# Epoch 149/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7570 - ssim_metric: 0.7952 - val_loss: 0.0268 - val_psnr_metric: 16.0191 - val_ssim_metric: 0.3441
# Epoch 150/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0022 - psnr_metric: 26.9565 - ssim_metric: 0.7976 - val_loss: 0.0266 - val_psnr_metric: 16.0270 - val_ssim_metric: 0.3458
# Epoch 151/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.1137 - ssim_metric: 0.8040 - val_loss: 0.0268 - val_psnr_metric: 16.0071 - val_ssim_metric: 0.3448
# Epoch 152/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.1064 - ssim_metric: 0.7997 - val_loss: 0.0267 - val_psnr_metric: 16.0075 - val_ssim_metric: 0.3458
# Epoch 153/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0022 - psnr_metric: 26.9790 - ssim_metric: 0.8001 - val_loss: 0.0268 - val_psnr_metric: 16.0135 - val_ssim_metric: 0.3474
# Epoch 154/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0022 - psnr_metric: 27.0062 - ssim_metric: 0.7971 - val_loss: 0.0267 - val_psnr_metric: 16.0271 - val_ssim_metric: 0.3487
# Epoch 155/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.1214 - ssim_metric: 0.8032 - val_loss: 0.0267 - val_psnr_metric: 16.0294 - val_ssim_metric: 0.3496
# Epoch 156/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.3149 - ssim_metric: 0.8097 - val_loss: 0.0268 - val_psnr_metric: 16.0011 - val_ssim_metric: 0.3474
# Epoch 157/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.1139 - ssim_metric: 0.8034 - val_loss: 0.0267 - val_psnr_metric: 16.0260 - val_ssim_metric: 0.3475
# Epoch 158/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.2560 - ssim_metric: 0.8061 - val_loss: 0.0267 - val_psnr_metric: 16.0227 - val_ssim_metric: 0.3453
# Epoch 159/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.1739 - ssim_metric: 0.8033 - val_loss: 0.0267 - val_psnr_metric: 16.0058 - val_ssim_metric: 0.3484
# Epoch 160/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.1815 - ssim_metric: 0.8044 - val_loss: 0.0268 - val_psnr_metric: 16.0013 - val_ssim_metric: 0.3468
# Epoch 161/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.3639 - ssim_metric: 0.8073 - val_loss: 0.0269 - val_psnr_metric: 15.9916 - val_ssim_metric: 0.3485
# Epoch 162/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.4188 - ssim_metric: 0.8084 - val_loss: 0.0268 - val_psnr_metric: 16.0037 - val_ssim_metric: 0.3484
# Epoch 163/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.4360 - ssim_metric: 0.8059 - val_loss: 0.0269 - val_psnr_metric: 15.9849 - val_ssim_metric: 0.3449
# Epoch 164/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.3495 - ssim_metric: 0.8066 - val_loss: 0.0268 - val_psnr_metric: 16.0020 - val_ssim_metric: 0.3512
# Epoch 165/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.2351 - ssim_metric: 0.8030 - val_loss: 0.0270 - val_psnr_metric: 15.9690 - val_ssim_metric: 0.3452
# Epoch 166/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0023 - psnr_metric: 26.7594 - ssim_metric: 0.7864 - val_loss: 0.0270 - val_psnr_metric: 15.9749 - val_ssim_metric: 0.3480
# Epoch 167/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.2039 - ssim_metric: 0.8023 - val_loss: 0.0267 - val_psnr_metric: 16.0254 - val_ssim_metric: 0.3514
# Epoch 168/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.6797 - ssim_metric: 0.8212 - val_loss: 0.0269 - val_psnr_metric: 15.9773 - val_ssim_metric: 0.3509
# Epoch 169/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.5872 - ssim_metric: 0.8119 - val_loss: 0.0268 - val_psnr_metric: 15.9978 - val_ssim_metric: 0.3517
# Epoch 170/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.5442 - ssim_metric: 0.8126 - val_loss: 0.0270 - val_psnr_metric: 15.9771 - val_ssim_metric: 0.3518
# Epoch 171/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.6476 - ssim_metric: 0.8171 - val_loss: 0.0269 - val_psnr_metric: 15.9731 - val_ssim_metric: 0.3493
# Epoch 172/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.2999 - ssim_metric: 0.8039 - val_loss: 0.0270 - val_psnr_metric: 15.9749 - val_ssim_metric: 0.3506
# Epoch 173/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.4943 - ssim_metric: 0.8113 - val_loss: 0.0269 - val_psnr_metric: 15.9815 - val_ssim_metric: 0.3517
# Epoch 174/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0021 - psnr_metric: 27.2873 - ssim_metric: 0.8049 - val_loss: 0.0270 - val_psnr_metric: 15.9633 - val_ssim_metric: 0.3506
# Epoch 175/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.7225 - ssim_metric: 0.8197 - val_loss: 0.0270 - val_psnr_metric: 15.9784 - val_ssim_metric: 0.3527
# Epoch 176/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.5835 - ssim_metric: 0.8179 - val_loss: 0.0268 - val_psnr_metric: 15.9968 - val_ssim_metric: 0.3549
# Epoch 177/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9983 - ssim_metric: 0.8248 - val_loss: 0.0269 - val_psnr_metric: 15.9797 - val_ssim_metric: 0.3513
# Epoch 178/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.4008 - ssim_metric: 0.8052 - val_loss: 0.0270 - val_psnr_metric: 15.9624 - val_ssim_metric: 0.3507
# Epoch 179/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.4997 - ssim_metric: 0.8109 - val_loss: 0.0270 - val_psnr_metric: 15.9629 - val_ssim_metric: 0.3507
# Epoch 180/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0020 - psnr_metric: 27.4859 - ssim_metric: 0.8080 - val_loss: 0.0270 - val_psnr_metric: 15.9585 - val_ssim_metric: 0.3526
# Epoch 181/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.7554 - ssim_metric: 0.8191 - val_loss: 0.0269 - val_psnr_metric: 15.9841 - val_ssim_metric: 0.3514
# Epoch 182/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.8843 - ssim_metric: 0.8152 - val_loss: 0.0271 - val_psnr_metric: 15.9640 - val_ssim_metric: 0.3529
# Epoch 183/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.6695 - ssim_metric: 0.8163 - val_loss: 0.0269 - val_psnr_metric: 15.9885 - val_ssim_metric: 0.3549
# Epoch 184/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.7494 - ssim_metric: 0.8201 - val_loss: 0.0269 - val_psnr_metric: 15.9684 - val_ssim_metric: 0.3543
# Epoch 185/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9532 - ssim_metric: 0.8205 - val_loss: 0.0270 - val_psnr_metric: 15.9538 - val_ssim_metric: 0.3532
# Epoch 186/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.7422 - ssim_metric: 0.8176 - val_loss: 0.0270 - val_psnr_metric: 15.9613 - val_ssim_metric: 0.3538
# Epoch 187/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.8856 - ssim_metric: 0.8154 - val_loss: 0.0271 - val_psnr_metric: 15.9529 - val_ssim_metric: 0.3559
# Epoch 188/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9961 - ssim_metric: 0.8242 - val_loss: 0.0271 - val_psnr_metric: 15.9509 - val_ssim_metric: 0.3534
# Epoch 189/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9604 - ssim_metric: 0.8245 - val_loss: 0.0271 - val_psnr_metric: 15.9477 - val_ssim_metric: 0.3566
# Epoch 190/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.8606 - ssim_metric: 0.8194 - val_loss: 0.0272 - val_psnr_metric: 15.9433 - val_ssim_metric: 0.3549
# Epoch 191/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0019 - psnr_metric: 27.5762 - ssim_metric: 0.8061 - val_loss: 0.0272 - val_psnr_metric: 15.9436 - val_ssim_metric: 0.3540
# Epoch 192/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9176 - ssim_metric: 0.8196 - val_loss: 0.0270 - val_psnr_metric: 15.9654 - val_ssim_metric: 0.3554
# Epoch 193/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1213 - ssim_metric: 0.8261 - val_loss: 0.0270 - val_psnr_metric: 15.9492 - val_ssim_metric: 0.3577
# Epoch 194/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.3694 - ssim_metric: 0.8351 - val_loss: 0.0271 - val_psnr_metric: 15.9591 - val_ssim_metric: 0.3568
# Epoch 195/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1969 - ssim_metric: 0.8267 - val_loss: 0.0270 - val_psnr_metric: 15.9568 - val_ssim_metric: 0.3548
# Epoch 196/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.0898 - ssim_metric: 0.8191 - val_loss: 0.0270 - val_psnr_metric: 15.9687 - val_ssim_metric: 0.3567
# Epoch 197/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.8611 - ssim_metric: 0.8134 - val_loss: 0.0271 - val_psnr_metric: 15.9459 - val_ssim_metric: 0.3549
# Epoch 198/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.8180 - ssim_metric: 0.8151 - val_loss: 0.0271 - val_psnr_metric: 15.9402 - val_ssim_metric: 0.3559
# Epoch 199/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.7533 - ssim_metric: 0.8129 - val_loss: 0.0271 - val_psnr_metric: 15.9442 - val_ssim_metric: 0.3545
# Epoch 200/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1216 - ssim_metric: 0.8242 - val_loss: 0.0270 - val_psnr_metric: 15.9579 - val_ssim_metric: 0.3587
# Epoch 201/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 28.0314 - ssim_metric: 0.8225 - val_loss: 0.0270 - val_psnr_metric: 15.9735 - val_ssim_metric: 0.3601
# Epoch 202/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1879 - ssim_metric: 0.8281 - val_loss: 0.0270 - val_psnr_metric: 15.9620 - val_ssim_metric: 0.3581
# Epoch 203/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.3085 - ssim_metric: 0.8315 - val_loss: 0.0271 - val_psnr_metric: 15.9439 - val_ssim_metric: 0.3547
# Epoch 204/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.8878 - ssim_metric: 0.8197 - val_loss: 0.0270 - val_psnr_metric: 15.9583 - val_ssim_metric: 0.3586
# Epoch 205/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1749 - ssim_metric: 0.8257 - val_loss: 0.0271 - val_psnr_metric: 15.9698 - val_ssim_metric: 0.3573
# Epoch 206/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9808 - ssim_metric: 0.8207 - val_loss: 0.0269 - val_psnr_metric: 15.9821 - val_ssim_metric: 0.3613
# Epoch 207/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.0634 - ssim_metric: 0.8212 - val_loss: 0.0271 - val_psnr_metric: 15.9570 - val_ssim_metric: 0.3600
# Epoch 208/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.2821 - ssim_metric: 0.8305 - val_loss: 0.0270 - val_psnr_metric: 15.9631 - val_ssim_metric: 0.3602
# Epoch 209/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.5343 - ssim_metric: 0.8377 - val_loss: 0.0271 - val_psnr_metric: 15.9563 - val_ssim_metric: 0.3589
# Epoch 210/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.3082 - ssim_metric: 0.8317 - val_loss: 0.0272 - val_psnr_metric: 15.9298 - val_ssim_metric: 0.3556
# Epoch 211/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1431 - ssim_metric: 0.8233 - val_loss: 0.0271 - val_psnr_metric: 15.9402 - val_ssim_metric: 0.3569
# Epoch 212/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.4145 - ssim_metric: 0.8311 - val_loss: 0.0270 - val_psnr_metric: 15.9644 - val_ssim_metric: 0.3584
# Epoch 213/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.3999 - ssim_metric: 0.8302 - val_loss: 0.0272 - val_psnr_metric: 15.9342 - val_ssim_metric: 0.3594
# Epoch 214/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5640 - ssim_metric: 0.8355 - val_loss: 0.0271 - val_psnr_metric: 15.9376 - val_ssim_metric: 0.3595
# Epoch 215/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5895 - ssim_metric: 0.8373 - val_loss: 0.0272 - val_psnr_metric: 15.9311 - val_ssim_metric: 0.3578
# Epoch 216/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1481 - ssim_metric: 0.8216 - val_loss: 0.0272 - val_psnr_metric: 15.9297 - val_ssim_metric: 0.3604
# Epoch 217/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0017 - psnr_metric: 28.1715 - ssim_metric: 0.8268 - val_loss: 0.0272 - val_psnr_metric: 15.9268 - val_ssim_metric: 0.3585
# Epoch 218/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.4065 - ssim_metric: 0.8292 - val_loss: 0.0273 - val_psnr_metric: 15.9246 - val_ssim_metric: 0.3586
# Epoch 219/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0018 - psnr_metric: 27.9732 - ssim_metric: 0.8170 - val_loss: 0.0271 - val_psnr_metric: 15.9526 - val_ssim_metric: 0.3593
# Epoch 220/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5630 - ssim_metric: 0.8332 - val_loss: 0.0272 - val_psnr_metric: 15.9340 - val_ssim_metric: 0.3606
# Epoch 221/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5667 - ssim_metric: 0.8375 - val_loss: 0.0271 - val_psnr_metric: 15.9569 - val_ssim_metric: 0.3606
# Epoch 222/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.6147 - ssim_metric: 0.8336 - val_loss: 0.0272 - val_psnr_metric: 15.9463 - val_ssim_metric: 0.3604
# Epoch 223/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.3910 - ssim_metric: 0.8313 - val_loss: 0.0271 - val_psnr_metric: 15.9451 - val_ssim_metric: 0.3615
# Epoch 224/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.4947 - ssim_metric: 0.8316 - val_loss: 0.0273 - val_psnr_metric: 15.9155 - val_ssim_metric: 0.3590
# Epoch 225/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.5318 - ssim_metric: 0.8314 - val_loss: 0.0273 - val_psnr_metric: 15.9114 - val_ssim_metric: 0.3598
# Epoch 226/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.4930 - ssim_metric: 0.8322 - val_loss: 0.0271 - val_psnr_metric: 15.9431 - val_ssim_metric: 0.3619
# Epoch 227/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.6252 - ssim_metric: 0.8348 - val_loss: 0.0273 - val_psnr_metric: 15.9162 - val_ssim_metric: 0.3615
# Epoch 228/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5999 - ssim_metric: 0.8362 - val_loss: 0.0272 - val_psnr_metric: 15.9329 - val_ssim_metric: 0.3615
# Epoch 229/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.8703 - ssim_metric: 0.8427 - val_loss: 0.0273 - val_psnr_metric: 15.9118 - val_ssim_metric: 0.3602
# Epoch 230/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5917 - ssim_metric: 0.8346 - val_loss: 0.0272 - val_psnr_metric: 15.9270 - val_ssim_metric: 0.3614
# Epoch 231/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.3742 - ssim_metric: 0.8265 - val_loss: 0.0272 - val_psnr_metric: 15.9412 - val_ssim_metric: 0.3640
# Epoch 232/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.4998 - ssim_metric: 0.8325 - val_loss: 0.0273 - val_psnr_metric: 15.9177 - val_ssim_metric: 0.3621
# Epoch 233/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.7095 - ssim_metric: 0.8387 - val_loss: 0.0273 - val_psnr_metric: 15.9220 - val_ssim_metric: 0.3646
# Epoch 234/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.6206 - ssim_metric: 0.8348 - val_loss: 0.0272 - val_psnr_metric: 15.9245 - val_ssim_metric: 0.3615
# Epoch 235/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.5222 - ssim_metric: 0.8311 - val_loss: 0.0274 - val_psnr_metric: 15.9056 - val_ssim_metric: 0.3599
# Epoch 236/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0015 - psnr_metric: 28.5492 - ssim_metric: 0.8316 - val_loss: 0.0272 - val_psnr_metric: 15.9309 - val_ssim_metric: 0.3633
# Epoch 237/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.7331 - ssim_metric: 0.8398 - val_loss: 0.0274 - val_psnr_metric: 15.9016 - val_ssim_metric: 0.3633
# Epoch 238/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.0283 - ssim_metric: 0.8449 - val_loss: 0.0273 - val_psnr_metric: 15.9168 - val_ssim_metric: 0.3615
# Epoch 239/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.4066 - ssim_metric: 0.8306 - val_loss: 0.0273 - val_psnr_metric: 15.9048 - val_ssim_metric: 0.3605
# Epoch 240/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.8821 - ssim_metric: 0.8419 - val_loss: 0.0272 - val_psnr_metric: 15.9271 - val_ssim_metric: 0.3633
# Epoch 241/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.6644 - ssim_metric: 0.8358 - val_loss: 0.0273 - val_psnr_metric: 15.9055 - val_ssim_metric: 0.3630
# Epoch 242/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.8955 - ssim_metric: 0.8412 - val_loss: 0.0271 - val_psnr_metric: 15.9336 - val_ssim_metric: 0.3642
# Epoch 243/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.7617 - ssim_metric: 0.8362 - val_loss: 0.0272 - val_psnr_metric: 15.9279 - val_ssim_metric: 0.3610
# Epoch 244/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5964 - ssim_metric: 0.8291 - val_loss: 0.0272 - val_psnr_metric: 15.9250 - val_ssim_metric: 0.3634
# Epoch 245/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.0988 - ssim_metric: 0.8473 - val_loss: 0.0273 - val_psnr_metric: 15.9159 - val_ssim_metric: 0.3622
# Epoch 246/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9903 - ssim_metric: 0.8446 - val_loss: 0.0273 - val_psnr_metric: 15.9244 - val_ssim_metric: 0.3648
# Epoch 247/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.5106 - ssim_metric: 0.8299 - val_loss: 0.0273 - val_psnr_metric: 15.9192 - val_ssim_metric: 0.3643
# Epoch 248/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0016 - psnr_metric: 28.5168 - ssim_metric: 0.8318 - val_loss: 0.0272 - val_psnr_metric: 15.9242 - val_ssim_metric: 0.3647
# Epoch 249/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.2473 - ssim_metric: 0.8488 - val_loss: 0.0272 - val_psnr_metric: 15.9227 - val_ssim_metric: 0.3646
# Epoch 250/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.1201 - ssim_metric: 0.8510 - val_loss: 0.0274 - val_psnr_metric: 15.8991 - val_ssim_metric: 0.3627
# Epoch 251/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.8666 - ssim_metric: 0.8389 - val_loss: 0.0273 - val_psnr_metric: 15.9122 - val_ssim_metric: 0.3632
# Epoch 252/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9515 - ssim_metric: 0.8414 - val_loss: 0.0272 - val_psnr_metric: 15.9208 - val_ssim_metric: 0.3645
# Epoch 253/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.8101 - ssim_metric: 0.8358 - val_loss: 0.0273 - val_psnr_metric: 15.9217 - val_ssim_metric: 0.3658
# Epoch 254/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9524 - ssim_metric: 0.8422 - val_loss: 0.0274 - val_psnr_metric: 15.9034 - val_ssim_metric: 0.3644
# Epoch 255/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.1954 - ssim_metric: 0.8475 - val_loss: 0.0272 - val_psnr_metric: 15.9228 - val_ssim_metric: 0.3668
# Epoch 256/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.5404 - ssim_metric: 0.8565 - val_loss: 0.0273 - val_psnr_metric: 15.9062 - val_ssim_metric: 0.3662
# Epoch 257/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.1265 - ssim_metric: 0.8463 - val_loss: 0.0273 - val_psnr_metric: 15.9092 - val_ssim_metric: 0.3647
# Epoch 258/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9270 - ssim_metric: 0.8404 - val_loss: 0.0273 - val_psnr_metric: 15.9137 - val_ssim_metric: 0.3623
# Epoch 259/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.5085 - ssim_metric: 0.8279 - val_loss: 0.0272 - val_psnr_metric: 15.9280 - val_ssim_metric: 0.3675
# Epoch 260/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.6574 - ssim_metric: 0.8332 - val_loss: 0.0273 - val_psnr_metric: 15.9129 - val_ssim_metric: 0.3674
# Epoch 261/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.3921 - ssim_metric: 0.8540 - val_loss: 0.0274 - val_psnr_metric: 15.8803 - val_ssim_metric: 0.3648
# Epoch 262/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.6042 - ssim_metric: 0.8557 - val_loss: 0.0274 - val_psnr_metric: 15.9044 - val_ssim_metric: 0.3642
# Epoch 263/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.1224 - ssim_metric: 0.8451 - val_loss: 0.0274 - val_psnr_metric: 15.9103 - val_ssim_metric: 0.3657
# Epoch 264/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9237 - ssim_metric: 0.8426 - val_loss: 0.0273 - val_psnr_metric: 15.9167 - val_ssim_metric: 0.3672
# Epoch 265/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9215 - ssim_metric: 0.8396 - val_loss: 0.0273 - val_psnr_metric: 15.9050 - val_ssim_metric: 0.3674
# Epoch 266/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.9786 - ssim_metric: 0.8411 - val_loss: 0.0273 - val_psnr_metric: 15.9099 - val_ssim_metric: 0.3654
# Epoch 267/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.3676 - ssim_metric: 0.8489 - val_loss: 0.0273 - val_psnr_metric: 15.9051 - val_ssim_metric: 0.3665
# Epoch 268/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.5556 - ssim_metric: 0.8544 - val_loss: 0.0275 - val_psnr_metric: 15.8973 - val_ssim_metric: 0.3649
# Epoch 269/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.2002 - ssim_metric: 0.8472 - val_loss: 0.0274 - val_psnr_metric: 15.8900 - val_ssim_metric: 0.3659
# Epoch 270/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 28.8414 - ssim_metric: 0.8379 - val_loss: 0.0274 - val_psnr_metric: 15.9025 - val_ssim_metric: 0.3670
# Epoch 271/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.3368 - ssim_metric: 0.8490 - val_loss: 0.0272 - val_psnr_metric: 15.9304 - val_ssim_metric: 0.3683
# Epoch 272/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.5090 - ssim_metric: 0.8557 - val_loss: 0.0274 - val_psnr_metric: 15.8959 - val_ssim_metric: 0.3658
# Epoch 273/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.2682 - ssim_metric: 0.8478 - val_loss: 0.0273 - val_psnr_metric: 15.9176 - val_ssim_metric: 0.3675
# Epoch 274/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.5446 - ssim_metric: 0.8535 - val_loss: 0.0273 - val_psnr_metric: 15.9044 - val_ssim_metric: 0.3682
# Epoch 275/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.5690 - ssim_metric: 0.8545 - val_loss: 0.0274 - val_psnr_metric: 15.9021 - val_ssim_metric: 0.3662
# Epoch 276/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.0939 - ssim_metric: 0.8427 - val_loss: 0.0274 - val_psnr_metric: 15.8957 - val_ssim_metric: 0.3658
# Epoch 277/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0014 - psnr_metric: 29.0119 - ssim_metric: 0.8411 - val_loss: 0.0274 - val_psnr_metric: 15.8949 - val_ssim_metric: 0.3646
# Epoch 278/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.2026 - ssim_metric: 0.8450 - val_loss: 0.0272 - val_psnr_metric: 15.9218 - val_ssim_metric: 0.3686
# Epoch 279/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.1940 - ssim_metric: 0.8438 - val_loss: 0.0274 - val_psnr_metric: 15.8817 - val_ssim_metric: 0.3660
# Epoch 280/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.7417 - ssim_metric: 0.8361 - val_loss: 0.0274 - val_psnr_metric: 15.9025 - val_ssim_metric: 0.3660
# Epoch 281/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.4389 - ssim_metric: 0.8513 - val_loss: 0.0273 - val_psnr_metric: 15.9062 - val_ssim_metric: 0.3684
# Epoch 282/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.7293 - ssim_metric: 0.8596 - val_loss: 0.0274 - val_psnr_metric: 15.8933 - val_ssim_metric: 0.3667
# Epoch 283/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.5160 - ssim_metric: 0.8557 - val_loss: 0.0273 - val_psnr_metric: 15.8980 - val_ssim_metric: 0.3670
# Epoch 284/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.5812 - ssim_metric: 0.8555 - val_loss: 0.0275 - val_psnr_metric: 15.8752 - val_ssim_metric: 0.3660
# Epoch 285/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.3548 - ssim_metric: 0.8476 - val_loss: 0.0274 - val_psnr_metric: 15.8859 - val_ssim_metric: 0.3687
# Epoch 286/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0015 - psnr_metric: 28.7067 - ssim_metric: 0.8313 - val_loss: 0.0274 - val_psnr_metric: 15.8857 - val_ssim_metric: 0.3681
# Epoch 287/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.4715 - ssim_metric: 0.8533 - val_loss: 0.0273 - val_psnr_metric: 15.9123 - val_ssim_metric: 0.3686
# Epoch 288/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.4981 - ssim_metric: 0.8533 - val_loss: 0.0273 - val_psnr_metric: 15.9077 - val_ssim_metric: 0.3696
# Epoch 289/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.7300 - ssim_metric: 0.8572 - val_loss: 0.0273 - val_psnr_metric: 15.9064 - val_ssim_metric: 0.3706
# Epoch 290/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0011 - psnr_metric: 29.9762 - ssim_metric: 0.8640 - val_loss: 0.0273 - val_psnr_metric: 15.9139 - val_ssim_metric: 0.3688
# Epoch 291/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.4817 - ssim_metric: 0.8514 - val_loss: 0.0274 - val_psnr_metric: 15.8840 - val_ssim_metric: 0.3676
# Epoch 292/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.2426 - ssim_metric: 0.8486 - val_loss: 0.0273 - val_psnr_metric: 15.8993 - val_ssim_metric: 0.3676
# Epoch 293/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.4549 - ssim_metric: 0.8508 - val_loss: 0.0273 - val_psnr_metric: 15.9169 - val_ssim_metric: 0.3714
# Epoch 294/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.3545 - ssim_metric: 0.8494 - val_loss: 0.0274 - val_psnr_metric: 15.8873 - val_ssim_metric: 0.3680
# Epoch 295/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0013 - psnr_metric: 29.3867 - ssim_metric: 0.8480 - val_loss: 0.0274 - val_psnr_metric: 15.8902 - val_ssim_metric: 0.3667
# Epoch 296/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.6306 - ssim_metric: 0.8543 - val_loss: 0.0274 - val_psnr_metric: 15.8769 - val_ssim_metric: 0.3675
# Epoch 297/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0011 - psnr_metric: 29.9911 - ssim_metric: 0.8601 - val_loss: 0.0273 - val_psnr_metric: 15.9074 - val_ssim_metric: 0.3708
# Epoch 298/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0012 - psnr_metric: 29.8149 - ssim_metric: 0.8615 - val_loss: 0.0273 - val_psnr_metric: 15.8942 - val_ssim_metric: 0.3702
# Epoch 299/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0011 - psnr_metric: 30.1185 - ssim_metric: 0.8670 - val_loss: 0.0274 - val_psnr_metric: 15.8869 - val_ssim_metric: 0.3696
# Epoch 300/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0011 - psnr_metric: 29.9565 - ssim_metric: 0.8630 - val_loss: 0.0275 - val_psnr_metric: 15.8765 - val_ssim_metric: 0.3681

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'psnr_metric', 'ssim_metric', 'val_loss', 'val_psnr_metric', 'val_ssim_metric'])

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['ssim_metric'], label='Training SSIM')
plt.plot(history.history['val_ssim_metric'], label='Test SSIM')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test SSIM')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['psnr_metric'], label='Training PSNR')
plt.plot(history.history['val_psnr_metric'], label='Test PSNR')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test PSNR')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluation by Plotting Images

# %%
import matplotlib.pyplot as plt

i = 50# index of sample
pred = model.predict(x_train[i:i+1])[0]

plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(x_train[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(y_train[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(pred.squeeze(), cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
import matplotlib.pyplot as plt

i = 0# index of sample
pred = model.predict(x_test[i:i+1])[0]

plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(x_test[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(y_test[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(pred.squeeze(), cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %% [markdown]
# ## Evaluate using PSNR and SSIM

# %%
import tensorflow as tf
import numpy as np

total_psnr = 0.0
total_ssim = 0.0
n = len(x_test)

for i in range(n):
    pred = model.predict(x_test[i:i+1], verbose=0)  # shape: (1, 256, 256, 1)
    gt = y_test[i:i+1]

    # Compute PSNR and SSIM
    psnr_val = tf.image.psnr(gt, pred, max_val=1.0).numpy()[0]
    ssim_val = tf.image.ssim(gt, pred, max_val=1.0).numpy()[0]

    total_psnr += psnr_val
    total_ssim += ssim_val

# Average metrics
avg_psnr = total_psnr / n
avg_ssim = total_ssim / n

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average SSIM: {avg_ssim:.4f}")
# Out:
# Average PSNR: 15.88 dB
# Average SSIM: 0.3681

# %%
import tensorflow as tf
import numpy as np

total_psnr = 0.0
total_ssim = 0.0
n = len(x_test)

for i in range(n):
    pred = model.predict(x_train[i:i+1], verbose=0)  # shape: (1, 256, 256, 1)
    gt = y_train[i:i+1]

    # Compute PSNR and SSIM
    psnr_val = tf.image.psnr(gt, pred, max_val=1.0).numpy()[0]
    ssim_val = tf.image.ssim(gt, pred, max_val=1.0).numpy()[0]

    total_psnr += psnr_val
    total_ssim += ssim_val

# Average metrics
avg_psnr = total_psnr / n
avg_ssim = total_ssim / n

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average SSIM: {avg_ssim:.4f}")
# Out:
# Average PSNR: 29.58 dB
# Average SSIM: 0.8741

# %% [markdown]
# # Plot

# %%
model.save('automap_model_dense_300epoch.h5')
