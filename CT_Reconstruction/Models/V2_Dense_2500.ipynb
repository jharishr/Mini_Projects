# %%
import tensorflow as tf
import os
import numpy as np
import time
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# Paths
input_dir = '/kaggle/input/brain-ct-sinograms-64-augmented-2-0/Datasets/brain_CT_sinograms_64_augmented'
output_dir = '/kaggle/input/brain-ct-sinograms-64-augmented-2-0/Datasets/brain_CT_64_augmented'

# Get sorted file names (to ensure matching)
input_files = sorted(os.listdir(input_dir))
output_files = sorted(os.listdir(output_dir))

# %%
# Initialize lists
x_data = []
y_data = []

# Load images
for in_file, out_file in zip(input_files, output_files):
    # Load grayscale image and resize to (256, 256)
    input_img = load_img(os.path.join(input_dir, in_file), color_mode='grayscale', target_size=(91,64))
    output_img = load_img(os.path.join(output_dir, out_file), color_mode='grayscale', target_size=(64, 64))
    
    # Convert to array and normalize to [0, 1]
    x = img_to_array(input_img) / 255.0
    y = img_to_array(output_img) / 255.0

    x_data.append(x)
    y_data.append(y)

# Convert to NumPy arrays
x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

print("Input shape:", x_data.shape)   # (125, 256, 256, 1)
print("Output shape:", y_data.shape)  # (125, 256, 256, 1)
# Out:
# Input shape: (2500, 91, 64, 1)
# Output shape: (2500, 64, 64, 1)

# %%
x_train = x_data[:2000]
x_test = x_data[2000:]
y_train = y_data[:2000]
y_test = y_data[2000:]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (2000, 91, 64, 1)
# (2000, 64, 64, 1)

# %%
index = 4

import matplotlib.pyplot as plt
plt.subplot(1, 2, 1)
plt.imshow(x_data[index].squeeze(), cmap='gray')
plt.title('Input (Sinogram)')

plt.subplot(1, 2, 2)
plt.imshow(y_data[index].squeeze(), cmap='gray')
plt.title('Output (CT Image)')
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Mean

def psnr_metric(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim_metric(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
from tensorflow.keras import models, layers
def build_automap(input_shape=(91, 64, 1), dropout_rate=0.3):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Resizing(64, 64),
        layers.Flatten(),
        layers.Dense(4096, activation='relu'),
        layers.Dense(4096, activation='tanh'),
        layers.Reshape((64, 64, 1))  # 👈 This fixes the shape
    ])
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
model = build_automap()
model.compile(optimizer=Adam(learning_rate=1e-4), loss=MeanSquaredError(), metrics=[psnr_metric, ssim_metric])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resizing_2 (Resizing)                │ (None, 64, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 64, 64, 1)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 33,562,624 (128.03 MB)
#  Trainable params: 33,562,624 (128.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# # Training
# history = model.fit(
#     x_train, y_train,
#     validation_data=(x_test, y_test),
#     batch_size=10,
#     epochs= ,
#     verbose=1
# )

# %%
import matplotlib.pyplot as plt

# Assuming you already have:
# model = build_automap(...)
# and your data: x_train, y_train, x_val, y_val

history = model.fit(
    x_train, y_train,
    epochs=300,
    batch_size=8,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0563 - psnr_metric: 12.9481 - ssim_metric: 0.1047 - val_loss: 0.0329 - val_psnr_metric: 14.9207 - val_ssim_metric: 0.1881
# Epoch 2/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0329 - psnr_metric: 14.9636 - ssim_metric: 0.2042 - val_loss: 0.0290 - val_psnr_metric: 15.5124 - val_ssim_metric: 0.2272
# Epoch 3/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0291 - psnr_metric: 15.5332 - ssim_metric: 0.2495 - val_loss: 0.0275 - val_psnr_metric: 15.7688 - val_ssim_metric: 0.2439
# Epoch 4/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0268 - psnr_metric: 15.9010 - ssim_metric: 0.2744 - val_loss: 0.0259 - val_psnr_metric: 16.0406 - val_ssim_metric: 0.2618
# Epoch 5/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0250 - psnr_metric: 16.2194 - ssim_metric: 0.2952 - val_loss: 0.0252 - val_psnr_metric: 16.1481 - val_ssim_metric: 0.2786
# Epoch 6/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0239 - psnr_metric: 16.4228 - ssim_metric: 0.3130 - val_loss: 0.0238 - val_psnr_metric: 16.4152 - val_ssim_metric: 0.2891
# Epoch 7/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0227 - psnr_metric: 16.6612 - ssim_metric: 0.3278 - val_loss: 0.0229 - val_psnr_metric: 16.5944 - val_ssim_metric: 0.3123
# Epoch 8/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0219 - psnr_metric: 16.8303 - ssim_metric: 0.3435 - val_loss: 0.0225 - val_psnr_metric: 16.6824 - val_ssim_metric: 0.3173
# Epoch 9/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0207 - psnr_metric: 17.0700 - ssim_metric: 0.3529 - val_loss: 0.0220 - val_psnr_metric: 16.7861 - val_ssim_metric: 0.3318
# Epoch 10/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0206 - psnr_metric: 17.0895 - ssim_metric: 0.3609 - val_loss: 0.0214 - val_psnr_metric: 16.9179 - val_ssim_metric: 0.3286
# Epoch 11/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0199 - psnr_metric: 17.2732 - ssim_metric: 0.3760 - val_loss: 0.0211 - val_psnr_metric: 16.9801 - val_ssim_metric: 0.3364
# Epoch 12/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0193 - psnr_metric: 17.3960 - ssim_metric: 0.3818 - val_loss: 0.0211 - val_psnr_metric: 16.9804 - val_ssim_metric: 0.3575
# Epoch 13/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0187 - psnr_metric: 17.5400 - ssim_metric: 0.3952 - val_loss: 0.0207 - val_psnr_metric: 17.0550 - val_ssim_metric: 0.3483
# Epoch 14/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0182 - psnr_metric: 17.6556 - ssim_metric: 0.3989 - val_loss: 0.0200 - val_psnr_metric: 17.2181 - val_ssim_metric: 0.3611
# Epoch 15/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0177 - psnr_metric: 17.7817 - ssim_metric: 0.4052 - val_loss: 0.0198 - val_psnr_metric: 17.2677 - val_ssim_metric: 0.3631
# Epoch 16/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0175 - psnr_metric: 17.8159 - ssim_metric: 0.4121 - val_loss: 0.0201 - val_psnr_metric: 17.1998 - val_ssim_metric: 0.3659
# Epoch 17/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0170 - psnr_metric: 17.9348 - ssim_metric: 0.4204 - val_loss: 0.0193 - val_psnr_metric: 17.3607 - val_ssim_metric: 0.3778
# Epoch 18/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0168 - psnr_metric: 17.9992 - ssim_metric: 0.4252 - val_loss: 0.0190 - val_psnr_metric: 17.4308 - val_ssim_metric: 0.3704
# Epoch 19/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0163 - psnr_metric: 18.1351 - ssim_metric: 0.4324 - val_loss: 0.0189 - val_psnr_metric: 17.4627 - val_ssim_metric: 0.3779
# Epoch 20/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0163 - psnr_metric: 18.1391 - ssim_metric: 0.4337 - val_loss: 0.0187 - val_psnr_metric: 17.4956 - val_ssim_metric: 0.3671
# Epoch 21/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0157 - psnr_metric: 18.3178 - ssim_metric: 0.4417 - val_loss: 0.0184 - val_psnr_metric: 17.5814 - val_ssim_metric: 0.3823
# Epoch 22/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0154 - psnr_metric: 18.3921 - ssim_metric: 0.4492 - val_loss: 0.0186 - val_psnr_metric: 17.5386 - val_ssim_metric: 0.3815
# Epoch 23/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0154 - psnr_metric: 18.3974 - ssim_metric: 0.4530 - val_loss: 0.0185 - val_psnr_metric: 17.5566 - val_ssim_metric: 0.3867
# Epoch 24/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0150 - psnr_metric: 18.4987 - ssim_metric: 0.4536 - val_loss: 0.0184 - val_psnr_metric: 17.5757 - val_ssim_metric: 0.3797
# Epoch 25/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0148 - psnr_metric: 18.5585 - ssim_metric: 0.4620 - val_loss: 0.0181 - val_psnr_metric: 17.6523 - val_ssim_metric: 0.3967
# Epoch 26/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0145 - psnr_metric: 18.6732 - ssim_metric: 0.4671 - val_loss: 0.0179 - val_psnr_metric: 17.6960 - val_ssim_metric: 0.3946
# Epoch 27/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0141 - psnr_metric: 18.7779 - ssim_metric: 0.4681 - val_loss: 0.0178 - val_psnr_metric: 17.7363 - val_ssim_metric: 0.3997
# Epoch 28/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0143 - psnr_metric: 18.7192 - ssim_metric: 0.4717 - val_loss: 0.0176 - val_psnr_metric: 17.7962 - val_ssim_metric: 0.3973
# Epoch 29/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0139 - psnr_metric: 18.8547 - ssim_metric: 0.4771 - val_loss: 0.0175 - val_psnr_metric: 17.8040 - val_ssim_metric: 0.4060
# Epoch 30/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0137 - psnr_metric: 18.9093 - ssim_metric: 0.4832 - val_loss: 0.0178 - val_psnr_metric: 17.7429 - val_ssim_metric: 0.4038
# Epoch 31/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0135 - psnr_metric: 18.9756 - ssim_metric: 0.4846 - val_loss: 0.0174 - val_psnr_metric: 17.8211 - val_ssim_metric: 0.3952
# Epoch 32/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0133 - psnr_metric: 19.0313 - ssim_metric: 0.4892 - val_loss: 0.0176 - val_psnr_metric: 17.7683 - val_ssim_metric: 0.4031
# Epoch 33/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0134 - psnr_metric: 19.0135 - ssim_metric: 0.4896 - val_loss: 0.0175 - val_psnr_metric: 17.8039 - val_ssim_metric: 0.4005
# Epoch 34/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0129 - psnr_metric: 19.1739 - ssim_metric: 0.4943 - val_loss: 0.0174 - val_psnr_metric: 17.8408 - val_ssim_metric: 0.4109
# Epoch 35/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0129 - psnr_metric: 19.1814 - ssim_metric: 0.4961 - val_loss: 0.0171 - val_psnr_metric: 17.9177 - val_ssim_metric: 0.4053
# Epoch 36/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0129 - psnr_metric: 19.1853 - ssim_metric: 0.4989 - val_loss: 0.0178 - val_psnr_metric: 17.7324 - val_ssim_metric: 0.4146
# Epoch 37/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0126 - psnr_metric: 19.2588 - ssim_metric: 0.4973 - val_loss: 0.0172 - val_psnr_metric: 17.9009 - val_ssim_metric: 0.4189
# Epoch 38/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0126 - psnr_metric: 19.2801 - ssim_metric: 0.5056 - val_loss: 0.0169 - val_psnr_metric: 17.9580 - val_ssim_metric: 0.4123
# Epoch 39/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0124 - psnr_metric: 19.3330 - ssim_metric: 0.5089 - val_loss: 0.0171 - val_psnr_metric: 17.9219 - val_ssim_metric: 0.4148
# Epoch 40/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0122 - psnr_metric: 19.4167 - ssim_metric: 0.5128 - val_loss: 0.0170 - val_psnr_metric: 17.9262 - val_ssim_metric: 0.4188
# Epoch 41/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0123 - psnr_metric: 19.3910 - ssim_metric: 0.5106 - val_loss: 0.0168 - val_psnr_metric: 17.9795 - val_ssim_metric: 0.4111
# Epoch 42/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0120 - psnr_metric: 19.5033 - ssim_metric: 0.5160 - val_loss: 0.0168 - val_psnr_metric: 17.9886 - val_ssim_metric: 0.4261
# Epoch 43/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0119 - psnr_metric: 19.5503 - ssim_metric: 0.5202 - val_loss: 0.0167 - val_psnr_metric: 18.0169 - val_ssim_metric: 0.4231
# Epoch 44/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0117 - psnr_metric: 19.5930 - ssim_metric: 0.5207 - val_loss: 0.0167 - val_psnr_metric: 18.0093 - val_ssim_metric: 0.4081
# Epoch 45/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0118 - psnr_metric: 19.5905 - ssim_metric: 0.5201 - val_loss: 0.0172 - val_psnr_metric: 17.8917 - val_ssim_metric: 0.4167
# Epoch 46/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0118 - psnr_metric: 19.5685 - ssim_metric: 0.5273 - val_loss: 0.0165 - val_psnr_metric: 18.0689 - val_ssim_metric: 0.4280
# Epoch 47/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0115 - psnr_metric: 19.6652 - ssim_metric: 0.5294 - val_loss: 0.0164 - val_psnr_metric: 18.0989 - val_ssim_metric: 0.4160
# Epoch 48/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0114 - psnr_metric: 19.7292 - ssim_metric: 0.5312 - val_loss: 0.0166 - val_psnr_metric: 18.0384 - val_ssim_metric: 0.4230
# Epoch 49/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0112 - psnr_metric: 19.8079 - ssim_metric: 0.5320 - val_loss: 0.0165 - val_psnr_metric: 18.0748 - val_ssim_metric: 0.4225
# Epoch 50/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0112 - psnr_metric: 19.8137 - ssim_metric: 0.5337 - val_loss: 0.0165 - val_psnr_metric: 18.0698 - val_ssim_metric: 0.4276
# Epoch 51/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0112 - psnr_metric: 19.7822 - ssim_metric: 0.5355 - val_loss: 0.0164 - val_psnr_metric: 18.0812 - val_ssim_metric: 0.4245
# Epoch 52/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0109 - psnr_metric: 19.9269 - ssim_metric: 0.5400 - val_loss: 0.0164 - val_psnr_metric: 18.0832 - val_ssim_metric: 0.4272
# Epoch 53/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0108 - psnr_metric: 19.9332 - ssim_metric: 0.5454 - val_loss: 0.0162 - val_psnr_metric: 18.1320 - val_ssim_metric: 0.4259
# Epoch 54/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0108 - psnr_metric: 19.9451 - ssim_metric: 0.5418 - val_loss: 0.0168 - val_psnr_metric: 18.0028 - val_ssim_metric: 0.4268
# Epoch 55/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0107 - psnr_metric: 19.9955 - ssim_metric: 0.5471 - val_loss: 0.0166 - val_psnr_metric: 18.0362 - val_ssim_metric: 0.4319
# Epoch 56/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0105 - psnr_metric: 20.0881 - ssim_metric: 0.5491 - val_loss: 0.0164 - val_psnr_metric: 18.0954 - val_ssim_metric: 0.4292
# Epoch 57/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0106 - psnr_metric: 20.0184 - ssim_metric: 0.5521 - val_loss: 0.0170 - val_psnr_metric: 17.9372 - val_ssim_metric: 0.4249
# Epoch 58/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0104 - psnr_metric: 20.1161 - ssim_metric: 0.5505 - val_loss: 0.0166 - val_psnr_metric: 18.0295 - val_ssim_metric: 0.4298
# Epoch 59/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0104 - psnr_metric: 20.1219 - ssim_metric: 0.5543 - val_loss: 0.0163 - val_psnr_metric: 18.1273 - val_ssim_metric: 0.4361
# Epoch 60/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0101 - psnr_metric: 20.2297 - ssim_metric: 0.5580 - val_loss: 0.0167 - val_psnr_metric: 18.0154 - val_ssim_metric: 0.4295
# Epoch 61/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0100 - psnr_metric: 20.2689 - ssim_metric: 0.5574 - val_loss: 0.0168 - val_psnr_metric: 17.9782 - val_ssim_metric: 0.4299
# Epoch 62/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0102 - psnr_metric: 20.1964 - ssim_metric: 0.5569 - val_loss: 0.0166 - val_psnr_metric: 18.0331 - val_ssim_metric: 0.4275
# Epoch 63/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0098 - psnr_metric: 20.3974 - ssim_metric: 0.5601 - val_loss: 0.0161 - val_psnr_metric: 18.1644 - val_ssim_metric: 0.4320
# Epoch 64/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0099 - psnr_metric: 20.3320 - ssim_metric: 0.5600 - val_loss: 0.0170 - val_psnr_metric: 17.9265 - val_ssim_metric: 0.4349
# Epoch 65/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0099 - psnr_metric: 20.3310 - ssim_metric: 0.5632 - val_loss: 0.0161 - val_psnr_metric: 18.1660 - val_ssim_metric: 0.4363
# Epoch 66/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0097 - psnr_metric: 20.4382 - ssim_metric: 0.5692 - val_loss: 0.0164 - val_psnr_metric: 18.0748 - val_ssim_metric: 0.4340
# Epoch 67/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0098 - psnr_metric: 20.3815 - ssim_metric: 0.5698 - val_loss: 0.0160 - val_psnr_metric: 18.2075 - val_ssim_metric: 0.4318
# Epoch 68/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0095 - psnr_metric: 20.4937 - ssim_metric: 0.5709 - val_loss: 0.0161 - val_psnr_metric: 18.1596 - val_ssim_metric: 0.4304
# Epoch 69/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0094 - psnr_metric: 20.5544 - ssim_metric: 0.5696 - val_loss: 0.0161 - val_psnr_metric: 18.1768 - val_ssim_metric: 0.4318
# Epoch 70/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0096 - psnr_metric: 20.4778 - ssim_metric: 0.5719 - val_loss: 0.0162 - val_psnr_metric: 18.1380 - val_ssim_metric: 0.4271
# Epoch 71/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0094 - psnr_metric: 20.5601 - ssim_metric: 0.5736 - val_loss: 0.0161 - val_psnr_metric: 18.1780 - val_ssim_metric: 0.4330
# Epoch 72/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0092 - psnr_metric: 20.6437 - ssim_metric: 0.5755 - val_loss: 0.0159 - val_psnr_metric: 18.2089 - val_ssim_metric: 0.4344
# Epoch 73/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0092 - psnr_metric: 20.6584 - ssim_metric: 0.5810 - val_loss: 0.0162 - val_psnr_metric: 18.1409 - val_ssim_metric: 0.4338
# Epoch 74/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0093 - psnr_metric: 20.6008 - ssim_metric: 0.5792 - val_loss: 0.0159 - val_psnr_metric: 18.2134 - val_ssim_metric: 0.4302
# Epoch 75/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0091 - psnr_metric: 20.7073 - ssim_metric: 0.5824 - val_loss: 0.0158 - val_psnr_metric: 18.2483 - val_ssim_metric: 0.4326
# Epoch 76/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0091 - psnr_metric: 20.7051 - ssim_metric: 0.5831 - val_loss: 0.0161 - val_psnr_metric: 18.1804 - val_ssim_metric: 0.4393
# Epoch 77/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0090 - psnr_metric: 20.7397 - ssim_metric: 0.5853 - val_loss: 0.0162 - val_psnr_metric: 18.1250 - val_ssim_metric: 0.4345
# Epoch 78/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0090 - psnr_metric: 20.7522 - ssim_metric: 0.5864 - val_loss: 0.0160 - val_psnr_metric: 18.1879 - val_ssim_metric: 0.4380
# Epoch 79/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0089 - psnr_metric: 20.7921 - ssim_metric: 0.5890 - val_loss: 0.0160 - val_psnr_metric: 18.1981 - val_ssim_metric: 0.4347
# Epoch 80/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0088 - psnr_metric: 20.8686 - ssim_metric: 0.5930 - val_loss: 0.0160 - val_psnr_metric: 18.1886 - val_ssim_metric: 0.4224
# Epoch 81/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0089 - psnr_metric: 20.7641 - ssim_metric: 0.5871 - val_loss: 0.0159 - val_psnr_metric: 18.2187 - val_ssim_metric: 0.4389
# Epoch 82/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0087 - psnr_metric: 20.9167 - ssim_metric: 0.5907 - val_loss: 0.0158 - val_psnr_metric: 18.2408 - val_ssim_metric: 0.4367
# Epoch 83/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0087 - psnr_metric: 20.8915 - ssim_metric: 0.5948 - val_loss: 0.0158 - val_psnr_metric: 18.2529 - val_ssim_metric: 0.4373
# Epoch 84/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0086 - psnr_metric: 20.9482 - ssim_metric: 0.5959 - val_loss: 0.0160 - val_psnr_metric: 18.1976 - val_ssim_metric: 0.4396
# Epoch 85/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0085 - psnr_metric: 20.9781 - ssim_metric: 0.5984 - val_loss: 0.0163 - val_psnr_metric: 18.1105 - val_ssim_metric: 0.4380
# Epoch 86/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0086 - psnr_metric: 20.9555 - ssim_metric: 0.5945 - val_loss: 0.0165 - val_psnr_metric: 18.0649 - val_ssim_metric: 0.4376
# Epoch 87/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0084 - psnr_metric: 21.0189 - ssim_metric: 0.6002 - val_loss: 0.0158 - val_psnr_metric: 18.2571 - val_ssim_metric: 0.4314
# Epoch 88/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0082 - psnr_metric: 21.1614 - ssim_metric: 0.6015 - val_loss: 0.0160 - val_psnr_metric: 18.1913 - val_ssim_metric: 0.4407
# Epoch 89/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0083 - psnr_metric: 21.1019 - ssim_metric: 0.6059 - val_loss: 0.0161 - val_psnr_metric: 18.1775 - val_ssim_metric: 0.4370
# Epoch 90/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0083 - psnr_metric: 21.1220 - ssim_metric: 0.6044 - val_loss: 0.0160 - val_psnr_metric: 18.2041 - val_ssim_metric: 0.4403
# Epoch 91/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0081 - psnr_metric: 21.1786 - ssim_metric: 0.6065 - val_loss: 0.0160 - val_psnr_metric: 18.1901 - val_ssim_metric: 0.4351
# Epoch 92/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0081 - psnr_metric: 21.2053 - ssim_metric: 0.6019 - val_loss: 0.0163 - val_psnr_metric: 18.1319 - val_ssim_metric: 0.4412
# Epoch 93/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0080 - psnr_metric: 21.2491 - ssim_metric: 0.6111 - val_loss: 0.0158 - val_psnr_metric: 18.2586 - val_ssim_metric: 0.4447
# Epoch 94/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0082 - psnr_metric: 21.1417 - ssim_metric: 0.6096 - val_loss: 0.0158 - val_psnr_metric: 18.2502 - val_ssim_metric: 0.4374
# Epoch 95/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0080 - psnr_metric: 21.2464 - ssim_metric: 0.6121 - val_loss: 0.0159 - val_psnr_metric: 18.2233 - val_ssim_metric: 0.4405
# Epoch 96/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0078 - psnr_metric: 21.3326 - ssim_metric: 0.6153 - val_loss: 0.0160 - val_psnr_metric: 18.1967 - val_ssim_metric: 0.4351
# Epoch 97/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0079 - psnr_metric: 21.2589 - ssim_metric: 0.6096 - val_loss: 0.0158 - val_psnr_metric: 18.2415 - val_ssim_metric: 0.4364
# Epoch 98/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0079 - psnr_metric: 21.3129 - ssim_metric: 0.6137 - val_loss: 0.0159 - val_psnr_metric: 18.2218 - val_ssim_metric: 0.4448
# Epoch 99/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0078 - psnr_metric: 21.3570 - ssim_metric: 0.6177 - val_loss: 0.0157 - val_psnr_metric: 18.2629 - val_ssim_metric: 0.4398
# Epoch 100/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0077 - psnr_metric: 21.4329 - ssim_metric: 0.6164 - val_loss: 0.0160 - val_psnr_metric: 18.2081 - val_ssim_metric: 0.4430
# Epoch 101/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0077 - psnr_metric: 21.4150 - ssim_metric: 0.6197 - val_loss: 0.0160 - val_psnr_metric: 18.1868 - val_ssim_metric: 0.4400
# Epoch 102/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0076 - psnr_metric: 21.4589 - ssim_metric: 0.6158 - val_loss: 0.0159 - val_psnr_metric: 18.2210 - val_ssim_metric: 0.4405
# Epoch 103/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0076 - psnr_metric: 21.4648 - ssim_metric: 0.6197 - val_loss: 0.0158 - val_psnr_metric: 18.2470 - val_ssim_metric: 0.4389
# Epoch 104/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0076 - psnr_metric: 21.4868 - ssim_metric: 0.6213 - val_loss: 0.0162 - val_psnr_metric: 18.1398 - val_ssim_metric: 0.4441
# Epoch 105/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0074 - psnr_metric: 21.5914 - ssim_metric: 0.6225 - val_loss: 0.0158 - val_psnr_metric: 18.2602 - val_ssim_metric: 0.4404
# Epoch 106/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0074 - psnr_metric: 21.5899 - ssim_metric: 0.6253 - val_loss: 0.0159 - val_psnr_metric: 18.2148 - val_ssim_metric: 0.4451
# Epoch 107/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0074 - psnr_metric: 21.5788 - ssim_metric: 0.6234 - val_loss: 0.0162 - val_psnr_metric: 18.1456 - val_ssim_metric: 0.4441
# Epoch 108/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0075 - psnr_metric: 21.5260 - ssim_metric: 0.6282 - val_loss: 0.0161 - val_psnr_metric: 18.1743 - val_ssim_metric: 0.4408
# Epoch 109/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0073 - psnr_metric: 21.6327 - ssim_metric: 0.6272 - val_loss: 0.0160 - val_psnr_metric: 18.2067 - val_ssim_metric: 0.4448
# Epoch 110/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0074 - psnr_metric: 21.5514 - ssim_metric: 0.6211 - val_loss: 0.0160 - val_psnr_metric: 18.1847 - val_ssim_metric: 0.4454
# Epoch 111/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0073 - psnr_metric: 21.6295 - ssim_metric: 0.6287 - val_loss: 0.0159 - val_psnr_metric: 18.2150 - val_ssim_metric: 0.4423
# Epoch 112/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0073 - psnr_metric: 21.6600 - ssim_metric: 0.6314 - val_loss: 0.0165 - val_psnr_metric: 18.0529 - val_ssim_metric: 0.4426
# Epoch 113/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0072 - psnr_metric: 21.6813 - ssim_metric: 0.6303 - val_loss: 0.0166 - val_psnr_metric: 18.0234 - val_ssim_metric: 0.4428
# Epoch 114/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0074 - psnr_metric: 21.5976 - ssim_metric: 0.6329 - val_loss: 0.0161 - val_psnr_metric: 18.1848 - val_ssim_metric: 0.4423
# Epoch 115/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0072 - psnr_metric: 21.6942 - ssim_metric: 0.6303 - val_loss: 0.0164 - val_psnr_metric: 18.0932 - val_ssim_metric: 0.4403
# Epoch 116/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - psnr_metric: 21.8111 - ssim_metric: 0.6337 - val_loss: 0.0159 - val_psnr_metric: 18.2076 - val_ssim_metric: 0.4432
# Epoch 117/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - psnr_metric: 21.8545 - ssim_metric: 0.6345 - val_loss: 0.0160 - val_psnr_metric: 18.2084 - val_ssim_metric: 0.4471
# Epoch 118/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - psnr_metric: 21.8481 - ssim_metric: 0.6387 - val_loss: 0.0161 - val_psnr_metric: 18.1607 - val_ssim_metric: 0.4438
# Epoch 119/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - psnr_metric: 21.8804 - ssim_metric: 0.6395 - val_loss: 0.0162 - val_psnr_metric: 18.1301 - val_ssim_metric: 0.4373
# Epoch 120/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - psnr_metric: 21.8263 - ssim_metric: 0.6342 - val_loss: 0.0162 - val_psnr_metric: 18.1430 - val_ssim_metric: 0.4475
# Epoch 121/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0068 - psnr_metric: 21.9655 - ssim_metric: 0.6412 - val_loss: 0.0161 - val_psnr_metric: 18.1685 - val_ssim_metric: 0.4468
# Epoch 122/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - psnr_metric: 21.9032 - ssim_metric: 0.6434 - val_loss: 0.0162 - val_psnr_metric: 18.1457 - val_ssim_metric: 0.4442
# Epoch 123/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - psnr_metric: 21.8705 - ssim_metric: 0.6407 - val_loss: 0.0163 - val_psnr_metric: 18.1143 - val_ssim_metric: 0.4426
# Epoch 124/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0068 - psnr_metric: 21.9304 - ssim_metric: 0.6404 - val_loss: 0.0165 - val_psnr_metric: 18.0509 - val_ssim_metric: 0.4388
# Epoch 125/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0069 - psnr_metric: 21.8389 - ssim_metric: 0.6413 - val_loss: 0.0161 - val_psnr_metric: 18.1633 - val_ssim_metric: 0.4443
# Epoch 126/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - psnr_metric: 22.0303 - ssim_metric: 0.6474 - val_loss: 0.0162 - val_psnr_metric: 18.1473 - val_ssim_metric: 0.4453
# Epoch 127/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0066 - psnr_metric: 22.0429 - ssim_metric: 0.6470 - val_loss: 0.0161 - val_psnr_metric: 18.1730 - val_ssim_metric: 0.4427
# Epoch 128/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0067 - psnr_metric: 22.0093 - ssim_metric: 0.6444 - val_loss: 0.0164 - val_psnr_metric: 18.0752 - val_ssim_metric: 0.4398
# Epoch 129/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067 - psnr_metric: 22.0394 - ssim_metric: 0.6506 - val_loss: 0.0162 - val_psnr_metric: 18.1428 - val_ssim_metric: 0.4378
# Epoch 130/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0066 - psnr_metric: 22.0548 - ssim_metric: 0.6462 - val_loss: 0.0163 - val_psnr_metric: 18.1250 - val_ssim_metric: 0.4493
# Epoch 131/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - psnr_metric: 22.1299 - ssim_metric: 0.6482 - val_loss: 0.0162 - val_psnr_metric: 18.1488 - val_ssim_metric: 0.4469
# Epoch 132/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - psnr_metric: 22.1136 - ssim_metric: 0.6535 - val_loss: 0.0161 - val_psnr_metric: 18.1522 - val_ssim_metric: 0.4396
# Epoch 133/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - psnr_metric: 22.1917 - ssim_metric: 0.6520 - val_loss: 0.0161 - val_psnr_metric: 18.1582 - val_ssim_metric: 0.4458
# Epoch 134/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0066 - psnr_metric: 22.0907 - ssim_metric: 0.6535 - val_loss: 0.0162 - val_psnr_metric: 18.1312 - val_ssim_metric: 0.4434
# Epoch 135/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - psnr_metric: 22.1162 - ssim_metric: 0.6546 - val_loss: 0.0163 - val_psnr_metric: 18.1153 - val_ssim_metric: 0.4412
# Epoch 136/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - psnr_metric: 22.1449 - ssim_metric: 0.6535 - val_loss: 0.0162 - val_psnr_metric: 18.1232 - val_ssim_metric: 0.4441
# Epoch 137/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - psnr_metric: 22.2446 - ssim_metric: 0.6478 - val_loss: 0.0164 - val_psnr_metric: 18.0864 - val_ssim_metric: 0.4450
# Epoch 138/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - psnr_metric: 22.2657 - ssim_metric: 0.6564 - val_loss: 0.0162 - val_psnr_metric: 18.1377 - val_ssim_metric: 0.4461
# Epoch 139/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0064 - psnr_metric: 22.2160 - ssim_metric: 0.6569 - val_loss: 0.0166 - val_psnr_metric: 18.0295 - val_ssim_metric: 0.4461
# Epoch 140/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - psnr_metric: 22.3095 - ssim_metric: 0.6579 - val_loss: 0.0163 - val_psnr_metric: 18.1125 - val_ssim_metric: 0.4432
# Epoch 141/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0063 - psnr_metric: 22.2597 - ssim_metric: 0.6565 - val_loss: 0.0162 - val_psnr_metric: 18.1370 - val_ssim_metric: 0.4427
# Epoch 142/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - psnr_metric: 22.2993 - ssim_metric: 0.6574 - val_loss: 0.0164 - val_psnr_metric: 18.0709 - val_ssim_metric: 0.4445
# Epoch 143/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - psnr_metric: 22.3449 - ssim_metric: 0.6619 - val_loss: 0.0164 - val_psnr_metric: 18.0750 - val_ssim_metric: 0.4431
# Epoch 144/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - psnr_metric: 22.3924 - ssim_metric: 0.6581 - val_loss: 0.0163 - val_psnr_metric: 18.1160 - val_ssim_metric: 0.4459
# Epoch 145/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - psnr_metric: 22.3588 - ssim_metric: 0.6586 - val_loss: 0.0163 - val_psnr_metric: 18.1005 - val_ssim_metric: 0.4470
# Epoch 146/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - psnr_metric: 22.3180 - ssim_metric: 0.6579 - val_loss: 0.0165 - val_psnr_metric: 18.0550 - val_ssim_metric: 0.4457
# Epoch 147/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - psnr_metric: 22.3607 - ssim_metric: 0.6620 - val_loss: 0.0164 - val_psnr_metric: 18.0937 - val_ssim_metric: 0.4476
# Epoch 148/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - psnr_metric: 22.3944 - ssim_metric: 0.6607 - val_loss: 0.0164 - val_psnr_metric: 18.0817 - val_ssim_metric: 0.4490
# Epoch 149/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0061 - psnr_metric: 22.4156 - ssim_metric: 0.6656 - val_loss: 0.0163 - val_psnr_metric: 18.1002 - val_ssim_metric: 0.4475
# Epoch 150/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - psnr_metric: 22.4583 - ssim_metric: 0.6694 - val_loss: 0.0165 - val_psnr_metric: 18.0568 - val_ssim_metric: 0.4459
# Epoch 151/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - psnr_metric: 22.4853 - ssim_metric: 0.6661 - val_loss: 0.0163 - val_psnr_metric: 18.1018 - val_ssim_metric: 0.4458
# Epoch 152/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - psnr_metric: 22.4686 - ssim_metric: 0.6636 - val_loss: 0.0166 - val_psnr_metric: 18.0225 - val_ssim_metric: 0.4435
# Epoch 153/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - psnr_metric: 22.4607 - ssim_metric: 0.6651 - val_loss: 0.0165 - val_psnr_metric: 18.0599 - val_ssim_metric: 0.4465
# Epoch 154/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - psnr_metric: 22.5450 - ssim_metric: 0.6682 - val_loss: 0.0165 - val_psnr_metric: 18.0597 - val_ssim_metric: 0.4433
# Epoch 155/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - psnr_metric: 22.5299 - ssim_metric: 0.6689 - val_loss: 0.0166 - val_psnr_metric: 18.0146 - val_ssim_metric: 0.4389
# Epoch 156/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - psnr_metric: 22.4916 - ssim_metric: 0.6630 - val_loss: 0.0165 - val_psnr_metric: 18.0454 - val_ssim_metric: 0.4457
# Epoch 157/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - psnr_metric: 22.5241 - ssim_metric: 0.6670 - val_loss: 0.0166 - val_psnr_metric: 18.0253 - val_ssim_metric: 0.4450
# Epoch 158/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - psnr_metric: 22.5571 - ssim_metric: 0.6708 - val_loss: 0.0167 - val_psnr_metric: 18.0051 - val_ssim_metric: 0.4412
# Epoch 159/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - psnr_metric: 22.6390 - ssim_metric: 0.6689 - val_loss: 0.0171 - val_psnr_metric: 17.8871 - val_ssim_metric: 0.4382
# Epoch 160/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - psnr_metric: 22.5467 - ssim_metric: 0.6622 - val_loss: 0.0165 - val_psnr_metric: 18.0431 - val_ssim_metric: 0.4457
# Epoch 161/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - psnr_metric: 22.6446 - ssim_metric: 0.6717 - val_loss: 0.0166 - val_psnr_metric: 18.0371 - val_ssim_metric: 0.4432
# Epoch 162/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - psnr_metric: 22.6785 - ssim_metric: 0.6721 - val_loss: 0.0166 - val_psnr_metric: 18.0263 - val_ssim_metric: 0.4445
# Epoch 163/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - psnr_metric: 22.7569 - ssim_metric: 0.6759 - val_loss: 0.0165 - val_psnr_metric: 18.0493 - val_ssim_metric: 0.4459
# Epoch 164/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - psnr_metric: 22.7354 - ssim_metric: 0.6728 - val_loss: 0.0165 - val_psnr_metric: 18.0537 - val_ssim_metric: 0.4425
# Epoch 165/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - psnr_metric: 22.6903 - ssim_metric: 0.6756 - val_loss: 0.0166 - val_psnr_metric: 18.0290 - val_ssim_metric: 0.4407
# Epoch 166/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - psnr_metric: 22.7053 - ssim_metric: 0.6751 - val_loss: 0.0166 - val_psnr_metric: 18.0168 - val_ssim_metric: 0.4421
# Epoch 167/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - psnr_metric: 22.7497 - ssim_metric: 0.6749 - val_loss: 0.0164 - val_psnr_metric: 18.0715 - val_ssim_metric: 0.4470
# Epoch 168/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - psnr_metric: 22.7853 - ssim_metric: 0.6777 - val_loss: 0.0165 - val_psnr_metric: 18.0520 - val_ssim_metric: 0.4444
# Epoch 169/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - psnr_metric: 22.8173 - ssim_metric: 0.6796 - val_loss: 0.0166 - val_psnr_metric: 18.0316 - val_ssim_metric: 0.4425
# Epoch 170/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - psnr_metric: 22.7954 - ssim_metric: 0.6783 - val_loss: 0.0164 - val_psnr_metric: 18.0848 - val_ssim_metric: 0.4457
# Epoch 171/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - psnr_metric: 22.8605 - ssim_metric: 0.6803 - val_loss: 0.0167 - val_psnr_metric: 17.9960 - val_ssim_metric: 0.4460
# Epoch 172/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - psnr_metric: 22.8035 - ssim_metric: 0.6789 - val_loss: 0.0166 - val_psnr_metric: 18.0041 - val_ssim_metric: 0.4398
# Epoch 173/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - psnr_metric: 22.8328 - ssim_metric: 0.6753 - val_loss: 0.0168 - val_psnr_metric: 17.9640 - val_ssim_metric: 0.4362
# Epoch 174/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - psnr_metric: 22.7786 - ssim_metric: 0.6738 - val_loss: 0.0168 - val_psnr_metric: 17.9774 - val_ssim_metric: 0.4425
# Epoch 175/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - psnr_metric: 22.9343 - ssim_metric: 0.6816 - val_loss: 0.0168 - val_psnr_metric: 17.9722 - val_ssim_metric: 0.4462
# Epoch 176/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - psnr_metric: 22.8838 - ssim_metric: 0.6807 - val_loss: 0.0167 - val_psnr_metric: 17.9982 - val_ssim_metric: 0.4436
# Epoch 177/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - psnr_metric: 22.8814 - ssim_metric: 0.6827 - val_loss: 0.0167 - val_psnr_metric: 18.0009 - val_ssim_metric: 0.4446
# Epoch 178/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - psnr_metric: 22.8844 - ssim_metric: 0.6814 - val_loss: 0.0168 - val_psnr_metric: 17.9671 - val_ssim_metric: 0.4471
# Epoch 179/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - psnr_metric: 22.9365 - ssim_metric: 0.6844 - val_loss: 0.0169 - val_psnr_metric: 17.9570 - val_ssim_metric: 0.4475
# Epoch 180/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - psnr_metric: 22.9917 - ssim_metric: 0.6843 - val_loss: 0.0167 - val_psnr_metric: 17.9881 - val_ssim_metric: 0.4431
# Epoch 181/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - psnr_metric: 22.9383 - ssim_metric: 0.6832 - val_loss: 0.0169 - val_psnr_metric: 17.9426 - val_ssim_metric: 0.4477
# Epoch 182/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - psnr_metric: 22.9854 - ssim_metric: 0.6863 - val_loss: 0.0168 - val_psnr_metric: 17.9637 - val_ssim_metric: 0.4448
# Epoch 183/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - psnr_metric: 22.9614 - ssim_metric: 0.6846 - val_loss: 0.0167 - val_psnr_metric: 17.9886 - val_ssim_metric: 0.4409
# Epoch 184/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.0873 - ssim_metric: 0.6907 - val_loss: 0.0170 - val_psnr_metric: 17.9264 - val_ssim_metric: 0.4388
# Epoch 185/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.0734 - ssim_metric: 0.6882 - val_loss: 0.0168 - val_psnr_metric: 17.9584 - val_ssim_metric: 0.4451
# Epoch 186/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.0480 - ssim_metric: 0.6863 - val_loss: 0.0170 - val_psnr_metric: 17.9304 - val_ssim_metric: 0.4429
# Epoch 187/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.1065 - ssim_metric: 0.6886 - val_loss: 0.0168 - val_psnr_metric: 17.9775 - val_ssim_metric: 0.4449
# Epoch 188/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - psnr_metric: 22.9993 - ssim_metric: 0.6834 - val_loss: 0.0169 - val_psnr_metric: 17.9541 - val_ssim_metric: 0.4424
# Epoch 189/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.1181 - ssim_metric: 0.6866 - val_loss: 0.0168 - val_psnr_metric: 17.9695 - val_ssim_metric: 0.4468
# Epoch 190/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.1225 - ssim_metric: 0.6927 - val_loss: 0.0169 - val_psnr_metric: 17.9470 - val_ssim_metric: 0.4435
# Epoch 191/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.0940 - ssim_metric: 0.6884 - val_loss: 0.0168 - val_psnr_metric: 17.9595 - val_ssim_metric: 0.4419
# Epoch 192/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0051 - psnr_metric: 23.1599 - ssim_metric: 0.6917 - val_loss: 0.0170 - val_psnr_metric: 17.9054 - val_ssim_metric: 0.4408
# Epoch 193/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.0984 - ssim_metric: 0.6864 - val_loss: 0.0169 - val_psnr_metric: 17.9589 - val_ssim_metric: 0.4423
# Epoch 194/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0051 - psnr_metric: 23.1488 - ssim_metric: 0.6890 - val_loss: 0.0171 - val_psnr_metric: 17.8834 - val_ssim_metric: 0.4459
# Epoch 195/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - psnr_metric: 23.2515 - ssim_metric: 0.6941 - val_loss: 0.0170 - val_psnr_metric: 17.9087 - val_ssim_metric: 0.4448
# Epoch 196/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - psnr_metric: 23.1225 - ssim_metric: 0.6934 - val_loss: 0.0170 - val_psnr_metric: 17.9129 - val_ssim_metric: 0.4380
# Epoch 197/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - psnr_metric: 23.2029 - ssim_metric: 0.6890 - val_loss: 0.0171 - val_psnr_metric: 17.8805 - val_ssim_metric: 0.4352
# Epoch 198/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0051 - psnr_metric: 23.1799 - ssim_metric: 0.6922 - val_loss: 0.0170 - val_psnr_metric: 17.9226 - val_ssim_metric: 0.4427
# Epoch 199/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - psnr_metric: 23.2108 - ssim_metric: 0.6947 - val_loss: 0.0171 - val_psnr_metric: 17.8993 - val_ssim_metric: 0.4449
# Epoch 200/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - psnr_metric: 23.2453 - ssim_metric: 0.6938 - val_loss: 0.0170 - val_psnr_metric: 17.9241 - val_ssim_metric: 0.4445
# Epoch 201/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.2971 - ssim_metric: 0.6968 - val_loss: 0.0171 - val_psnr_metric: 17.8973 - val_ssim_metric: 0.4429
# Epoch 202/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3222 - ssim_metric: 0.6970 - val_loss: 0.0171 - val_psnr_metric: 17.8915 - val_ssim_metric: 0.4429
# Epoch 203/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - psnr_metric: 23.2825 - ssim_metric: 0.6903 - val_loss: 0.0171 - val_psnr_metric: 17.9074 - val_ssim_metric: 0.4425
# Epoch 204/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.2902 - ssim_metric: 0.6961 - val_loss: 0.0171 - val_psnr_metric: 17.8910 - val_ssim_metric: 0.4408
# Epoch 205/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3072 - ssim_metric: 0.6971 - val_loss: 0.0173 - val_psnr_metric: 17.8414 - val_ssim_metric: 0.4382
# Epoch 206/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3655 - ssim_metric: 0.6956 - val_loss: 0.0173 - val_psnr_metric: 17.8430 - val_ssim_metric: 0.4399
# Epoch 207/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3250 - ssim_metric: 0.6954 - val_loss: 0.0171 - val_psnr_metric: 17.8929 - val_ssim_metric: 0.4406
# Epoch 208/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3081 - ssim_metric: 0.6937 - val_loss: 0.0172 - val_psnr_metric: 17.8681 - val_ssim_metric: 0.4418
# Epoch 209/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3098 - ssim_metric: 0.6946 - val_loss: 0.0171 - val_psnr_metric: 17.8814 - val_ssim_metric: 0.4445
# Epoch 210/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3291 - ssim_metric: 0.7019 - val_loss: 0.0171 - val_psnr_metric: 17.8916 - val_ssim_metric: 0.4415
# Epoch 211/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3750 - ssim_metric: 0.6941 - val_loss: 0.0172 - val_psnr_metric: 17.8603 - val_ssim_metric: 0.4423
# Epoch 212/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - psnr_metric: 23.3504 - ssim_metric: 0.6993 - val_loss: 0.0173 - val_psnr_metric: 17.8481 - val_ssim_metric: 0.4420
# Epoch 213/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0048 - psnr_metric: 23.3865 - ssim_metric: 0.6994 - val_loss: 0.0172 - val_psnr_metric: 17.8677 - val_ssim_metric: 0.4411
# Epoch 214/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0048 - psnr_metric: 23.4321 - ssim_metric: 0.7002 - val_loss: 0.0172 - val_psnr_metric: 17.8717 - val_ssim_metric: 0.4418
# Epoch 215/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5278 - ssim_metric: 0.7023 - val_loss: 0.0173 - val_psnr_metric: 17.8552 - val_ssim_metric: 0.4447
# Epoch 216/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0048 - psnr_metric: 23.4470 - ssim_metric: 0.6989 - val_loss: 0.0174 - val_psnr_metric: 17.8077 - val_ssim_metric: 0.4424
# Epoch 217/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.4738 - ssim_metric: 0.7003 - val_loss: 0.0172 - val_psnr_metric: 17.8677 - val_ssim_metric: 0.4408
# Epoch 218/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0048 - psnr_metric: 23.4567 - ssim_metric: 0.7047 - val_loss: 0.0172 - val_psnr_metric: 17.8645 - val_ssim_metric: 0.4433
# Epoch 219/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0048 - psnr_metric: 23.4567 - ssim_metric: 0.7018 - val_loss: 0.0173 - val_psnr_metric: 17.8340 - val_ssim_metric: 0.4426
# Epoch 220/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.4938 - ssim_metric: 0.7005 - val_loss: 0.0175 - val_psnr_metric: 17.7845 - val_ssim_metric: 0.4415
# Epoch 221/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.4929 - ssim_metric: 0.7037 - val_loss: 0.0175 - val_psnr_metric: 17.7785 - val_ssim_metric: 0.4427
# Epoch 222/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5363 - ssim_metric: 0.6986 - val_loss: 0.0176 - val_psnr_metric: 17.7742 - val_ssim_metric: 0.4423
# Epoch 223/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5263 - ssim_metric: 0.7055 - val_loss: 0.0173 - val_psnr_metric: 17.8238 - val_ssim_metric: 0.4395
# Epoch 224/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5400 - ssim_metric: 0.7012 - val_loss: 0.0177 - val_psnr_metric: 17.7349 - val_ssim_metric: 0.4451
# Epoch 225/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5500 - ssim_metric: 0.7067 - val_loss: 0.0176 - val_psnr_metric: 17.7751 - val_ssim_metric: 0.4407
# Epoch 226/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - psnr_metric: 23.5855 - ssim_metric: 0.7075 - val_loss: 0.0175 - val_psnr_metric: 17.7927 - val_ssim_metric: 0.4403
# Epoch 227/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - psnr_metric: 23.6224 - ssim_metric: 0.7091 - val_loss: 0.0176 - val_psnr_metric: 17.7685 - val_ssim_metric: 0.4399
# Epoch 228/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - psnr_metric: 23.5996 - ssim_metric: 0.7036 - val_loss: 0.0176 - val_psnr_metric: 17.7576 - val_ssim_metric: 0.4385
# Epoch 229/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5427 - ssim_metric: 0.7039 - val_loss: 0.0175 - val_psnr_metric: 17.7855 - val_ssim_metric: 0.4377
# Epoch 230/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - psnr_metric: 23.5439 - ssim_metric: 0.7016 - val_loss: 0.0174 - val_psnr_metric: 17.8050 - val_ssim_metric: 0.4375
# Epoch 231/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - psnr_metric: 23.6591 - ssim_metric: 0.7078 - val_loss: 0.0176 - val_psnr_metric: 17.7580 - val_ssim_metric: 0.4410
# Epoch 232/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - psnr_metric: 23.6974 - ssim_metric: 0.7086 - val_loss: 0.0177 - val_psnr_metric: 17.7501 - val_ssim_metric: 0.4415
# Epoch 233/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - psnr_metric: 23.6741 - ssim_metric: 0.7069 - val_loss: 0.0175 - val_psnr_metric: 17.7962 - val_ssim_metric: 0.4386
# Epoch 234/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - psnr_metric: 23.6386 - ssim_metric: 0.7060 - val_loss: 0.0175 - val_psnr_metric: 17.7725 - val_ssim_metric: 0.4379
# Epoch 235/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - psnr_metric: 23.6032 - ssim_metric: 0.7058 - val_loss: 0.0178 - val_psnr_metric: 17.7217 - val_ssim_metric: 0.4394
# Epoch 236/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - psnr_metric: 23.6438 - ssim_metric: 0.7069 - val_loss: 0.0175 - val_psnr_metric: 17.7914 - val_ssim_metric: 0.4384
# Epoch 237/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - psnr_metric: 23.6769 - ssim_metric: 0.7088 - val_loss: 0.0176 - val_psnr_metric: 17.7638 - val_ssim_metric: 0.4387
# Epoch 238/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - psnr_metric: 23.7155 - ssim_metric: 0.7081 - val_loss: 0.0177 - val_psnr_metric: 17.7468 - val_ssim_metric: 0.4421
# Epoch 239/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.8254 - ssim_metric: 0.7152 - val_loss: 0.0177 - val_psnr_metric: 17.7193 - val_ssim_metric: 0.4388
# Epoch 240/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - psnr_metric: 23.6708 - ssim_metric: 0.7050 - val_loss: 0.0176 - val_psnr_metric: 17.7569 - val_ssim_metric: 0.4405
# Epoch 241/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.7824 - ssim_metric: 0.7108 - val_loss: 0.0178 - val_psnr_metric: 17.7216 - val_ssim_metric: 0.4376
# Epoch 242/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.7963 - ssim_metric: 0.7088 - val_loss: 0.0176 - val_psnr_metric: 17.7632 - val_ssim_metric: 0.4375
# Epoch 243/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.8019 - ssim_metric: 0.7087 - val_loss: 0.0176 - val_psnr_metric: 17.7709 - val_ssim_metric: 0.4413
# Epoch 244/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.8783 - ssim_metric: 0.7154 - val_loss: 0.0177 - val_psnr_metric: 17.7485 - val_ssim_metric: 0.4402
# Epoch 245/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.7941 - ssim_metric: 0.7097 - val_loss: 0.0179 - val_psnr_metric: 17.6961 - val_ssim_metric: 0.4392
# Epoch 246/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.8507 - ssim_metric: 0.7152 - val_loss: 0.0178 - val_psnr_metric: 17.7140 - val_ssim_metric: 0.4382
# Epoch 247/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.8030 - ssim_metric: 0.7116 - val_loss: 0.0178 - val_psnr_metric: 17.7068 - val_ssim_metric: 0.4372
# Epoch 248/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.8210 - ssim_metric: 0.7114 - val_loss: 0.0179 - val_psnr_metric: 17.6992 - val_ssim_metric: 0.4406
# Epoch 249/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.8726 - ssim_metric: 0.7105 - val_loss: 0.0177 - val_psnr_metric: 17.7235 - val_ssim_metric: 0.4395
# Epoch 250/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - psnr_metric: 23.7932 - ssim_metric: 0.7101 - val_loss: 0.0181 - val_psnr_metric: 17.6298 - val_ssim_metric: 0.4378
# Epoch 251/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.8684 - ssim_metric: 0.7127 - val_loss: 0.0179 - val_psnr_metric: 17.6824 - val_ssim_metric: 0.4391
# Epoch 252/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.9509 - ssim_metric: 0.7158 - val_loss: 0.0178 - val_psnr_metric: 17.6978 - val_ssim_metric: 0.4387
# Epoch 253/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.8608 - ssim_metric: 0.7128 - val_loss: 0.0178 - val_psnr_metric: 17.6976 - val_ssim_metric: 0.4390
# Epoch 254/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.8721 - ssim_metric: 0.7176 - val_loss: 0.0180 - val_psnr_metric: 17.6634 - val_ssim_metric: 0.4403
# Epoch 255/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.9206 - ssim_metric: 0.7185 - val_loss: 0.0180 - val_psnr_metric: 17.6629 - val_ssim_metric: 0.4369
# Epoch 256/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - psnr_metric: 23.9192 - ssim_metric: 0.7152 - val_loss: 0.0179 - val_psnr_metric: 17.6775 - val_ssim_metric: 0.4400
# Epoch 257/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0042 - psnr_metric: 24.0021 - ssim_metric: 0.7157 - val_loss: 0.0179 - val_psnr_metric: 17.6921 - val_ssim_metric: 0.4380
# Epoch 258/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 23.9639 - ssim_metric: 0.7152 - val_loss: 0.0179 - val_psnr_metric: 17.6829 - val_ssim_metric: 0.4378
# Epoch 259/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 23.9953 - ssim_metric: 0.7175 - val_loss: 0.0179 - val_psnr_metric: 17.6771 - val_ssim_metric: 0.4386
# Epoch 260/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 24.0032 - ssim_metric: 0.7165 - val_loss: 0.0181 - val_psnr_metric: 17.6299 - val_ssim_metric: 0.4389
# Epoch 261/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 24.0055 - ssim_metric: 0.7147 - val_loss: 0.0179 - val_psnr_metric: 17.6770 - val_ssim_metric: 0.4355
# Epoch 262/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 24.0346 - ssim_metric: 0.7183 - val_loss: 0.0180 - val_psnr_metric: 17.6664 - val_ssim_metric: 0.4393
# Epoch 263/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0042 - psnr_metric: 23.9567 - ssim_metric: 0.7193 - val_loss: 0.0185 - val_psnr_metric: 17.5281 - val_ssim_metric: 0.4356
# Epoch 264/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 23.9459 - ssim_metric: 0.7124 - val_loss: 0.0180 - val_psnr_metric: 17.6535 - val_ssim_metric: 0.4343
# Epoch 265/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 23.9779 - ssim_metric: 0.7175 - val_loss: 0.0183 - val_psnr_metric: 17.5914 - val_ssim_metric: 0.4397
# Epoch 266/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 23.9751 - ssim_metric: 0.7164 - val_loss: 0.0181 - val_psnr_metric: 17.6429 - val_ssim_metric: 0.4381
# Epoch 267/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 24.0329 - ssim_metric: 0.7168 - val_loss: 0.0180 - val_psnr_metric: 17.6643 - val_ssim_metric: 0.4369
# Epoch 268/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - psnr_metric: 24.1173 - ssim_metric: 0.7226 - val_loss: 0.0181 - val_psnr_metric: 17.6331 - val_ssim_metric: 0.4380
# Epoch 269/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - psnr_metric: 24.0847 - ssim_metric: 0.7178 - val_loss: 0.0181 - val_psnr_metric: 17.6250 - val_ssim_metric: 0.4368
# Epoch 270/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 24.0220 - ssim_metric: 0.7209 - val_loss: 0.0181 - val_psnr_metric: 17.6352 - val_ssim_metric: 0.4390
# Epoch 271/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0042 - psnr_metric: 24.0205 - ssim_metric: 0.7202 - val_loss: 0.0182 - val_psnr_metric: 17.6016 - val_ssim_metric: 0.4394
# Epoch 272/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0041 - psnr_metric: 24.0886 - ssim_metric: 0.7177 - val_loss: 0.0185 - val_psnr_metric: 17.5284 - val_ssim_metric: 0.4372
# Epoch 273/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - psnr_metric: 24.0532 - ssim_metric: 0.7191 - val_loss: 0.0181 - val_psnr_metric: 17.6198 - val_ssim_metric: 0.4361
# Epoch 274/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - psnr_metric: 24.0372 - ssim_metric: 0.7174 - val_loss: 0.0181 - val_psnr_metric: 17.6461 - val_ssim_metric: 0.4401
# Epoch 275/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.1832 - ssim_metric: 0.7230 - val_loss: 0.0181 - val_psnr_metric: 17.6326 - val_ssim_metric: 0.4366
# Epoch 276/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.1857 - ssim_metric: 0.7207 - val_loss: 0.0183 - val_psnr_metric: 17.5796 - val_ssim_metric: 0.4359
# Epoch 277/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - psnr_metric: 24.0685 - ssim_metric: 0.7170 - val_loss: 0.0182 - val_psnr_metric: 17.6180 - val_ssim_metric: 0.4378
# Epoch 278/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0040 - psnr_metric: 24.1927 - ssim_metric: 0.7242 - val_loss: 0.0183 - val_psnr_metric: 17.5951 - val_ssim_metric: 0.4361
# Epoch 279/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0040 - psnr_metric: 24.1482 - ssim_metric: 0.7259 - val_loss: 0.0182 - val_psnr_metric: 17.6049 - val_ssim_metric: 0.4322
# Epoch 280/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.1811 - ssim_metric: 0.7230 - val_loss: 0.0183 - val_psnr_metric: 17.5897 - val_ssim_metric: 0.4364
# Epoch 281/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - psnr_metric: 24.1268 - ssim_metric: 0.7142 - val_loss: 0.0182 - val_psnr_metric: 17.6212 - val_ssim_metric: 0.4360
# Epoch 282/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.1591 - ssim_metric: 0.7227 - val_loss: 0.0183 - val_psnr_metric: 17.5764 - val_ssim_metric: 0.4343
# Epoch 283/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0041 - psnr_metric: 24.1231 - ssim_metric: 0.7192 - val_loss: 0.0182 - val_psnr_metric: 17.6069 - val_ssim_metric: 0.4392
# Epoch 284/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.2438 - ssim_metric: 0.7219 - val_loss: 0.0185 - val_psnr_metric: 17.5387 - val_ssim_metric: 0.4365
# Epoch 285/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.2116 - ssim_metric: 0.7238 - val_loss: 0.0182 - val_psnr_metric: 17.6144 - val_ssim_metric: 0.4356
# Epoch 286/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.1919 - ssim_metric: 0.7226 - val_loss: 0.0184 - val_psnr_metric: 17.5736 - val_ssim_metric: 0.4366
# Epoch 287/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - psnr_metric: 24.2721 - ssim_metric: 0.7254 - val_loss: 0.0183 - val_psnr_metric: 17.5937 - val_ssim_metric: 0.4385
# Epoch 288/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.2130 - ssim_metric: 0.7240 - val_loss: 0.0183 - val_psnr_metric: 17.5932 - val_ssim_metric: 0.4380
# Epoch 289/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - psnr_metric: 24.2554 - ssim_metric: 0.7215 - val_loss: 0.0183 - val_psnr_metric: 17.5802 - val_ssim_metric: 0.4352
# Epoch 290/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.2050 - ssim_metric: 0.7190 - val_loss: 0.0182 - val_psnr_metric: 17.6071 - val_ssim_metric: 0.4350
# Epoch 291/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.1731 - ssim_metric: 0.7228 - val_loss: 0.0184 - val_psnr_metric: 17.5690 - val_ssim_metric: 0.4371
# Epoch 292/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0040 - psnr_metric: 24.2554 - ssim_metric: 0.7247 - val_loss: 0.0185 - val_psnr_metric: 17.5309 - val_ssim_metric: 0.4295
# Epoch 293/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - psnr_metric: 24.2868 - ssim_metric: 0.7204 - val_loss: 0.0184 - val_psnr_metric: 17.5605 - val_ssim_metric: 0.4348
# Epoch 294/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - psnr_metric: 24.2913 - ssim_metric: 0.7269 - val_loss: 0.0186 - val_psnr_metric: 17.5158 - val_ssim_metric: 0.4342
# Epoch 295/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - psnr_metric: 24.2295 - ssim_metric: 0.7212 - val_loss: 0.0184 - val_psnr_metric: 17.5637 - val_ssim_metric: 0.4347
# Epoch 296/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - psnr_metric: 24.3075 - ssim_metric: 0.7322 - val_loss: 0.0186 - val_psnr_metric: 17.5127 - val_ssim_metric: 0.4309
# Epoch 297/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0039 - psnr_metric: 24.3499 - ssim_metric: 0.7278 - val_loss: 0.0185 - val_psnr_metric: 17.5353 - val_ssim_metric: 0.4327
# Epoch 298/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - psnr_metric: 24.3816 - ssim_metric: 0.7256 - val_loss: 0.0185 - val_psnr_metric: 17.5477 - val_ssim_metric: 0.4349
# Epoch 299/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - psnr_metric: 24.3804 - ssim_metric: 0.7293 - val_loss: 0.0185 - val_psnr_metric: 17.5390 - val_ssim_metric: 0.4368
# Epoch 300/300
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0039 - psnr_metric: 24.3005 - ssim_metric: 0.7265 - val_loss: 0.0186 - val_psnr_metric: 17.5174 - val_ssim_metric: 0.4296

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'psnr_metric', 'ssim_metric', 'val_loss', 'val_psnr_metric', 'val_ssim_metric'])

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['ssim_metric'], label='Training SSIM')
plt.plot(history.history['val_ssim_metric'], label='Test SSIM')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test SSIM')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['psnr_metric'], label='Training PSNR')
plt.plot(history.history['val_psnr_metric'], label='Test PSNR')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test PSNR')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluation by Plotting Images

# %%
import matplotlib.pyplot as plt

i = 50# index of sample
pred = model.predict(x_train[i:i+1])[0]

plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(x_train[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(y_train[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(pred.squeeze(), cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
import matplotlib.pyplot as plt

i = 50# index of sample
pred = model.predict(x_test[i:i+1])[0]

plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(x_test[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(y_test[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(pred.squeeze(), cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %% [markdown]
# ## Evaluate using PSNR and SSIM

# %%
import tensorflow as tf
import numpy as np

total_psnr = 0.0
total_ssim = 0.0
n = len(x_test)

for i in range(n):
    pred = model.predict(x_test[i:i+1], verbose=0)  # shape: (1, 256, 256, 1)
    gt = y_test[i:i+1]

    # Compute PSNR and SSIM
    psnr_val = tf.image.psnr(gt, pred, max_val=1.0).numpy()[0]
    ssim_val = tf.image.ssim(gt, pred, max_val=1.0).numpy()[0]

    total_psnr += psnr_val
    total_ssim += ssim_val

# Average metrics
avg_psnr = total_psnr / n
avg_ssim = total_ssim / n

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average SSIM: {avg_ssim:.4f}")
# Out:
# Average PSNR: 17.52 dB
# Average SSIM: 0.4296

# %%
import tensorflow as tf
import numpy as np

total_psnr = 0.0
total_ssim = 0.0
n = len(x_test)

for i in range(n):
    pred = model.predict(x_train[i:i+1], verbose=0)  # shape: (1, 256, 256, 1)
    gt = y_train[i:i+1]

    # Compute PSNR and SSIM
    psnr_val = tf.image.psnr(gt, pred, max_val=1.0).numpy()[0]
    ssim_val = tf.image.ssim(gt, pred, max_val=1.0).numpy()[0]

    total_psnr += psnr_val
    total_ssim += ssim_val

# Average metrics
avg_psnr = total_psnr / n
avg_ssim = total_ssim / n

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average SSIM: {avg_ssim:.4f}")
# Out:
# Average PSNR: 24.04 dB
# Average SSIM: 0.7408

# %%
model.save('automap_model_dense_300epoch.h5')
