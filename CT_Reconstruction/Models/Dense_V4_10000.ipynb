# %%
import tensorflow as tf
import os
import numpy as np
import time
from tensorflow.keras.preprocessing.image import load_img, img_to_array
# Out:
# 2025-07-03 05:50:09.161661: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751521809.323462      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751521809.381478      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Paths
input_dir = '/kaggle/input/brain-ct-sinograms-64-10000/Datasets/brain_CT_sinograms_64_augmented'
output_dir = '/kaggle/input/brain-ct-sinograms-64-10000/Datasets/brain_CT_64_augmented'

# Get sorted file names (to ensure matching)
input_files = sorted(os.listdir(input_dir))
output_files = sorted(os.listdir(output_dir))

# %%
# Initialize lists
x_data = []
y_data = []

# Load images
for in_file, out_file in zip(input_files, output_files):
    # Load grayscale image and resize to (256, 256)
    input_img = load_img(os.path.join(input_dir, in_file), color_mode='grayscale', target_size=(91,64))
    output_img = load_img(os.path.join(output_dir, out_file), color_mode='grayscale', target_size=(64, 64))
    
    # Convert to array and normalize to [0, 1]
    x = img_to_array(input_img) / 255.0
    y = img_to_array(output_img) / 255.0

    x_data.append(x)
    y_data.append(y)

# Convert to NumPy arrays
x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

print("Input shape:", x_data.shape)   # (125, 256, 256, 1)
print("Output shape:", y_data.shape)  # (125, 256, 256, 1)
# Out:
# Input shape: (10000, 91, 64, 1)
# Output shape: (10000, 64, 64, 1)

# %%
x_train = x_data[:9500]
x_test = x_data[9500:]
y_train = y_data[:9500]
y_test = y_data[9500:]

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (9500, 91, 64, 1)
# (9500, 64, 64, 1)

# %%
index = 4

import matplotlib.pyplot as plt
plt.subplot(1, 2, 1)
plt.imshow(x_data[index].squeeze(), cmap='gray')
plt.title('Input (Sinogram)')

plt.subplot(1, 2, 2)
plt.imshow(y_data[index].squeeze(), cmap='gray')
plt.title('Output (CT Image)')
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Mean

def psnr_metric(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

def ssim_metric(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
from tensorflow.keras import models, layers

def build_automap(input_shape=(91, 64, 1), dropout_rate=0.3):
    inputs = layers.Input(shape=input_shape)

    # Flatten the input
    x = layers.Flatten()(inputs)

    # Fully connected layers
    x = layers.Dense(91 * 64, activation='relu')(x)
    x = layers.Dense(64 * 64, activation='sigmoid')(x)  # sigmoid to keep output in [0,1]

    # Reshape to image
    outputs = layers.Reshape((64, 64, 1))(x)

    return models.Model(inputs, outputs)



from tensorflow.keras import layers, models

def build_automap_v4(input_shape=(91, 64, 1)):
    inputs = layers.Input(shape=input_shape)             # Sinogram input (90x128)
    x = layers.Flatten()(inputs)                         # Shape: (11520,)
    
    # Fully connected layer to 64x64
    x = layers.Dense(64 * 64, activation='tanh')(x)         # FC1
    x = layers.Reshape((64, 64, 1))(x)                   # Reshape for ConvNet
    
    # 1st Conv layer
    x = layers.Conv2D(128, (3, 3), padding='same', activation='tanh')(x)
    # 2nd Conv layer
    x = layers.Conv2D(128, (3, 3), padding='same', activation='tanh')(x)
    # 3rd Conv layer
    x = layers.Conv2D(128, (3, 3), padding='same', activation='tanh')(x)
    # 4th Conv layer
    x = layers.Conv2D(128, (3, 3), padding='same', activation='tanh')(x)
    # 5th Conv layer (final)
    x = layers.Conv2D(1, (3, 3), padding='same', activation='tanh')(x)
    
    return models.Model(inputs, x)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(patience=40, restore_best_weights=True)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
model = build_automap_v4()
model.compile(optimizer=Adam(learning_rate=1e-4), loss=MeanSquaredError(), metrics=[psnr_metric, ssim_metric])
# Out:
# I0000 00:00:1751521915.192158      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1751521915.192871      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 91, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 5824)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4096)                │      23,859,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 64, 64, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 64, 64, 128)         │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 64, 64, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 64, 64, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 64, 64, 1)           │           1,153 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,304,385 (92.71 MB)
#  Trainable params: 24,304,385 (92.71 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import matplotlib.pyplot as plt


history = model.fit(
    x_train, y_train,
    epochs=300,
    batch_size=8,
    validation_data=(x_test, y_test),
    callbacks = [early_stop]
)
# Out:
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751521926.192606      99 service.cc:148] XLA service 0x7a82ec0036b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751521926.193062      99 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1751521926.193077      99 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# W0000 00:00:1751521926.397723      99 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1751521926.398476      99 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# W0000 00:00:1751521926.399954      99 assert_op.cc:38] Ignoring Assert operator SSIM/Assert/Assert
# W0000 00:00:1751521926.400656      99 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_1/Assert
# W0000 00:00:1751521926.401516      99 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_2/Assert
# W0000 00:00:1751521926.402086      99 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_3/Assert
# I0000 00:00:1751521926.536003      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    7/1188 ━━━━━━━━━━━━━━━━━━━━ 23s 20ms/step - loss: 0.1328 - psnr_metric: 8.9132 - ssim_metric: 0.0614
# I0000 00:00:1751521929.645871      99 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0368 - psnr_metric: 14.7721 - ssim_metric: 0.2172
# W0000 00:00:1751521953.809422      96 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1751521953.809694      96 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# W0000 00:00:1751521953.810211      96 assert_op.cc:38] Ignoring Assert operator SSIM/Assert/Assert
# W0000 00:00:1751521953.810464      96 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_1/Assert
# W0000 00:00:1751521953.810740      96 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_2/Assert
# W0000 00:00:1751521953.810917      96 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_3/Assert
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0368 - psnr_metric: 14.7738 - ssim_metric: 0.2173
# W0000 00:00:1751521956.357379      97 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1751521956.358340      97 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# W0000 00:00:1751521956.360217      97 assert_op.cc:38] Ignoring Assert operator SSIM/Assert/Assert
# W0000 00:00:1751521956.360945      97 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_1/Assert
# W0000 00:00:1751521956.361850      97 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_2/Assert
# W0000 00:00:1751521956.362421      97 assert_op.cc:38] Ignoring Assert operator SSIM/Assert_3/Assert
# W0000 00:00:1751521957.163132      98 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1751521957.163354      98 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 35s 23ms/step - loss: 0.0368 - psnr_metric: 14.7746 - ssim_metric: 0.2174 - val_loss: 0.0223 - val_psnr_metric: 16.6976 - val_ssim_metric: 0.3505
# Epoch 2/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.0210 - psnr_metric: 17.0223 - ssim_metric: 0.3686 - val_loss: 0.0177 - val_psnr_metric: 17.8487 - val_ssim_metric: 0.4254
# Epoch 3/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0181 - psnr_metric: 17.6668 - ssim_metric: 0.4224 - val_loss: 0.0165 - val_psnr_metric: 18.1715 - val_ssim_metric: 0.4654
# Epoch 4/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - loss: 0.0164 - psnr_metric: 18.1193 - ssim_metric: 0.4698 - val_loss: 0.0158 - val_psnr_metric: 18.3157 - val_ssim_metric: 0.4815
# Epoch 5/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0153 - psnr_metric: 18.4748 - ssim_metric: 0.5169 - val_loss: 0.0150 - val_psnr_metric: 18.6545 - val_ssim_metric: 0.5284
# Epoch 6/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0141 - psnr_metric: 18.8717 - ssim_metric: 0.5464 - val_loss: 0.0141 - val_psnr_metric: 19.0284 - val_ssim_metric: 0.5316
# Epoch 7/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0133 - psnr_metric: 19.1579 - ssim_metric: 0.5666 - val_loss: 0.0134 - val_psnr_metric: 19.2202 - val_ssim_metric: 0.5714
# Epoch 8/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0126 - psnr_metric: 19.4204 - ssim_metric: 0.5876 - val_loss: 0.0141 - val_psnr_metric: 18.9619 - val_ssim_metric: 0.5633
# Epoch 9/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0120 - psnr_metric: 19.6402 - ssim_metric: 0.6015 - val_loss: 0.0131 - val_psnr_metric: 19.3372 - val_ssim_metric: 0.5791
# Epoch 10/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0116 - psnr_metric: 19.8099 - ssim_metric: 0.6105 - val_loss: 0.0125 - val_psnr_metric: 19.6089 - val_ssim_metric: 0.6037
# Epoch 11/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0111 - psnr_metric: 20.0400 - ssim_metric: 0.6230 - val_loss: 0.0127 - val_psnr_metric: 19.5077 - val_ssim_metric: 0.5909
# Epoch 12/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0108 - psnr_metric: 20.1450 - ssim_metric: 0.6300 - val_loss: 0.0123 - val_psnr_metric: 19.6914 - val_ssim_metric: 0.6181
# Epoch 13/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0104 - psnr_metric: 20.3382 - ssim_metric: 0.6412 - val_loss: 0.0126 - val_psnr_metric: 19.5267 - val_ssim_metric: 0.6087
# Epoch 14/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0102 - psnr_metric: 20.4393 - ssim_metric: 0.6464 - val_loss: 0.0124 - val_psnr_metric: 19.6042 - val_ssim_metric: 0.5950
# Epoch 15/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0099 - psnr_metric: 20.5388 - ssim_metric: 0.6535 - val_loss: 0.0115 - val_psnr_metric: 20.0040 - val_ssim_metric: 0.6387
# Epoch 16/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0096 - psnr_metric: 20.6868 - ssim_metric: 0.6577 - val_loss: 0.0112 - val_psnr_metric: 20.1536 - val_ssim_metric: 0.6394
# Epoch 17/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0094 - psnr_metric: 20.8044 - ssim_metric: 0.6680 - val_loss: 0.0110 - val_psnr_metric: 20.2439 - val_ssim_metric: 0.6538
# Epoch 18/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0092 - psnr_metric: 20.9019 - ssim_metric: 0.6722 - val_loss: 0.0121 - val_psnr_metric: 19.7106 - val_ssim_metric: 0.6335
# Epoch 19/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0091 - psnr_metric: 20.9706 - ssim_metric: 0.6694 - val_loss: 0.0109 - val_psnr_metric: 20.3208 - val_ssim_metric: 0.6459
# Epoch 20/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0088 - psnr_metric: 21.1093 - ssim_metric: 0.6836 - val_loss: 0.0110 - val_psnr_metric: 20.1869 - val_ssim_metric: 0.6500
# Epoch 21/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0087 - psnr_metric: 21.1565 - ssim_metric: 0.6824 - val_loss: 0.0105 - val_psnr_metric: 20.4630 - val_ssim_metric: 0.6701
# Epoch 22/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0086 - psnr_metric: 21.2601 - ssim_metric: 0.6896 - val_loss: 0.0107 - val_psnr_metric: 20.3674 - val_ssim_metric: 0.6401
# Epoch 23/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0085 - psnr_metric: 21.3080 - ssim_metric: 0.6895 - val_loss: 0.0110 - val_psnr_metric: 20.2071 - val_ssim_metric: 0.6409
# Epoch 24/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0084 - psnr_metric: 21.3519 - ssim_metric: 0.6935 - val_loss: 0.0109 - val_psnr_metric: 20.2513 - val_ssim_metric: 0.6603
# Epoch 25/300
# 1186/1188 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0082 - psnr_metric: 21.4283 - ssim_metric: 0.6947Epoch 26/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0080 - psnr_metric: 21.5286 - ssim_metric: 0.7026 - val_loss: 0.0107 - val_psnr_metric: 20.3546 - val_ssim_metric: 0.6616
# Epoch 27/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0080 - psnr_metric: 21.5933 - ssim_metric: 0.7054 - val_loss: 0.0100 - val_psnr_metric: 20.6668 - val_ssim_metric: 0.6714
# Epoch 28/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0079 - psnr_metric: 21.6496 - ssim_metric: 0.7096 - val_loss: 0.0099 - val_psnr_metric: 20.7627 - val_ssim_metric: 0.6932
# Epoch 29/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0077 - psnr_metric: 21.7775 - ssim_metric: 0.7161 - val_loss: 0.0099 - val_psnr_metric: 20.7441 - val_ssim_metric: 0.6360
# Epoch 30/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0076 - psnr_metric: 21.8188 - ssim_metric: 0.7269 - val_loss: 0.0105 - val_psnr_metric: 20.4146 - val_ssim_metric: 0.6414
# Epoch 31/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0076 - psnr_metric: 21.8158 - ssim_metric: 0.7324 - val_loss: 0.0106 - val_psnr_metric: 20.3911 - val_ssim_metric: 0.6284
# Epoch 32/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0074 - psnr_metric: 21.9387 - ssim_metric: 0.7390 - val_loss: 0.0099 - val_psnr_metric: 20.7607 - val_ssim_metric: 0.6984
# Epoch 33/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0073 - psnr_metric: 21.9633 - ssim_metric: 0.7313 - val_loss: 0.0099 - val_psnr_metric: 20.7634 - val_ssim_metric: 0.7110
# Epoch 34/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0072 - psnr_metric: 22.0766 - ssim_metric: 0.7402 - val_loss: 0.0097 - val_psnr_metric: 20.8503 - val_ssim_metric: 0.7001
# Epoch 35/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0071 - psnr_metric: 22.1167 - ssim_metric: 0.7413 - val_loss: 0.0098 - val_psnr_metric: 20.7796 - val_ssim_metric: 0.7248
# Epoch 36/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0070 - psnr_metric: 22.1762 - ssim_metric: 0.7491 - val_loss: 0.0093 - val_psnr_metric: 21.0407 - val_ssim_metric: 0.6954
# Epoch 37/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0070 - psnr_metric: 22.1499 - ssim_metric: 0.7489 - val_loss: 0.0094 - val_psnr_metric: 21.0043 - val_ssim_metric: 0.7263
# Epoch 38/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0069 - psnr_metric: 22.2624 - ssim_metric: 0.7467 - val_loss: 0.0100 - val_psnr_metric: 20.6771 - val_ssim_metric: 0.7128
# Epoch 39/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0068 - psnr_metric: 22.3307 - ssim_metric: 0.7572 - val_loss: 0.0094 - val_psnr_metric: 20.9792 - val_ssim_metric: 0.7223
# Epoch 40/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0067 - psnr_metric: 22.3597 - ssim_metric: 0.7532 - val_loss: 0.0094 - val_psnr_metric: 20.9329 - val_ssim_metric: 0.6808
# Epoch 41/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0067 - psnr_metric: 22.3896 - ssim_metric: 0.7648 - val_loss: 0.0093 - val_psnr_metric: 21.0434 - val_ssim_metric: 0.7197
# Epoch 42/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0066 - psnr_metric: 22.4196 - ssim_metric: 0.7638 - val_loss: 0.0093 - val_psnr_metric: 20.9812 - val_ssim_metric: 0.7110
# Epoch 43/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0065 - psnr_metric: 22.5030 - ssim_metric: 0.7608 - val_loss: 0.0091 - val_psnr_metric: 21.1059 - val_ssim_metric: 0.7308
# Epoch 44/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0065 - psnr_metric: 22.5469 - ssim_metric: 0.7703 - val_loss: 0.0091 - val_psnr_metric: 21.1365 - val_ssim_metric: 0.7371
# Epoch 45/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0064 - psnr_metric: 22.5462 - ssim_metric: 0.7732 - val_loss: 0.0089 - val_psnr_metric: 21.2423 - val_ssim_metric: 0.7195
# Epoch 46/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0063 - psnr_metric: 22.6031 - ssim_metric: 0.7668 - val_loss: 0.0090 - val_psnr_metric: 21.1572 - val_ssim_metric: 0.6886
# Epoch 47/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0063 - psnr_metric: 22.6296 - ssim_metric: 0.7660 - val_loss: 0.0088 - val_psnr_metric: 21.2039 - val_ssim_metric: 0.7455
# Epoch 48/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0062 - psnr_metric: 22.7008 - ssim_metric: 0.7730 - val_loss: 0.0090 - val_psnr_metric: 21.1354 - val_ssim_metric: 0.7459
# Epoch 49/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0062 - psnr_metric: 22.7499 - ssim_metric: 0.7773 - val_loss: 0.0090 - val_psnr_metric: 21.1768 - val_ssim_metric: 0.7395
# Epoch 50/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0061 - psnr_metric: 22.8145 - ssim_metric: 0.7798 - val_loss: 0.0097 - val_psnr_metric: 20.7737 - val_ssim_metric: 0.6265
# Epoch 51/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0061 - psnr_metric: 22.7925 - ssim_metric: 0.7714 - val_loss: 0.0087 - val_psnr_metric: 21.2738 - val_ssim_metric: 0.7499
# Epoch 52/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0060 - psnr_metric: 22.8487 - ssim_metric: 0.7810 - val_loss: 0.0085 - val_psnr_metric: 21.4174 - val_ssim_metric: 0.7318
# Epoch 53/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0059 - psnr_metric: 22.9195 - ssim_metric: 0.7863 - val_loss: 0.0087 - val_psnr_metric: 21.3062 - val_ssim_metric: 0.7489
# Epoch 54/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0057 - psnr_metric: 23.0847 - ssim_metric: 0.7928 - val_loss: 0.0086 - val_psnr_metric: 21.3386 - val_ssim_metric: 0.7388
# Epoch 61/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0056 - psnr_metric: 23.1028 - ssim_metric: 0.7958 - val_loss: 0.0084 - val_psnr_metric: 21.4440 - val_ssim_metric: 0.6712
# Epoch 62/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0055 - psnr_metric: 23.2119 - ssim_metric: 0.7960 - val_loss: 0.0086 - val_psnr_metric: 21.3350 - val_ssim_metric: 0.7325
# Epoch 63/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0055 - psnr_metric: 23.2418 - ssim_metric: 0.7978 - val_loss: 0.0087 - val_psnr_metric: 21.2836 - val_ssim_metric: 0.7251
# Epoch 64/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0055 - psnr_metric: 23.2102 - ssim_metric: 0.8019 - val_loss: 0.0089 - val_psnr_metric: 21.1630 - val_ssim_metric: 0.7193
# Epoch 65/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0055 - psnr_metric: 23.2313 - ssim_metric: 0.7978 - val_loss: 0.0081 - val_psnr_metric: 21.6611 - val_ssim_metric: 0.7692
# Epoch 66/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0054 - psnr_metric: 23.3204 - ssim_metric: 0.7979 - val_loss: 0.0082 - val_psnr_metric: 21.5371 - val_ssim_metric: 0.7752
# Epoch 67/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0054 - psnr_metric: 23.3063 - ssim_metric: 0.8060 - val_loss: 0.0084 - val_psnr_metric: 21.4320 - val_ssim_metric: 0.7733
# Epoch 68/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0053 - psnr_metric: 23.3746 - ssim_metric: 0.8065 - val_loss: 0.0082 - val_psnr_metric: 21.5441 - val_ssim_metric: 0.7328
# Epoch 69/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0053 - psnr_metric: 23.3359 - ssim_metric: 0.8069 - val_loss: 0.0083 - val_psnr_metric: 21.5169 - val_ssim_metric: 0.7396
# Epoch 70/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0050 - psnr_metric: 23.6329 - ssim_metric: 0.8222 - val_loss: 0.0081 - val_psnr_metric: 21.5921 - val_ssim_metric: 0.7719
# Epoch 79/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0047 - psnr_metric: 23.8714 - ssim_metric: 0.8271 - val_loss: 0.0079 - val_psnr_metric: 21.7193 - val_ssim_metric: 0.7858
# Epoch 93/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0046 - psnr_metric: 23.9609 - ssim_metric: 0.8313 - val_loss: 0.0079 - val_psnr_metric: 21.6623 - val_ssim_metric: 0.7082
# Epoch 94/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0047 - psnr_metric: 23.9142 - ssim_metric: 0.8326 - val_loss: 0.0081 - val_psnr_metric: 21.5983 - val_ssim_metric: 0.7617
# Epoch 95/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0046 - psnr_metric: 23.9654 - ssim_metric: 0.8330 - val_loss: 0.0078 - val_psnr_metric: 21.7774 - val_ssim_metric: 0.7892
# Epoch 96/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0045 - psnr_metric: 24.0495 - ssim_metric: 0.8331 - val_loss: 0.0080 - val_psnr_metric: 21.5993 - val_ssim_metric: 0.7880
# Epoch 99/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0046 - psnr_metric: 23.9957 - ssim_metric: 0.8315 - val_loss: 0.0076 - val_psnr_metric: 21.8750 - val_ssim_metric: 0.7853
# Epoch 100/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0046 - psnr_metric: 24.0130 - ssim_metric: 0.8382 - val_loss: 0.0077 - val_psnr_metric: 21.8073 - val_ssim_metric: 0.8061
# Epoch 101/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0046 - psnr_metric: 24.0176 - ssim_metric: 0.8386 - val_loss: 0.0080 - val_psnr_metric: 21.6212 - val_ssim_metric: 0.7616
# Epoch 102/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0045 - psnr_metric: 24.1174 - ssim_metric: 0.8335 - val_loss: 0.0076 - val_psnr_metric: 21.8758 - val_ssim_metric: 0.7967
# Epoch 103/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0045 - psnr_metric: 24.0721 - ssim_metric: 0.8404 - val_loss: 0.0077 - val_psnr_metric: 21.8137 - val_ssim_metric: 0.7851
# Epoch 104/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0044 - psnr_metric: 24.2071 - ssim_metric: 0.8428 - val_loss: 0.0076 - val_psnr_metric: 21.8411 - val_ssim_metric: 0.8065
# Epoch 111/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0044 - psnr_metric: 24.1924 - ssim_metric: 0.8400 - val_loss: 0.0075 - val_psnr_metric: 21.9441 - val_ssim_metric: 0.7992
# Epoch 112/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0043 - psnr_metric: 24.2450 - ssim_metric: 0.8438 - val_loss: 0.0076 - val_psnr_metric: 21.8711 - val_ssim_metric: 0.7845
# Epoch 113/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0043 - psnr_metric: 24.2735 - ssim_metric: 0.8408 - val_loss: 0.0075 - val_psnr_metric: 21.9331 - val_ssim_metric: 0.8048
# Epoch 114/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0043 - psnr_metric: 24.2966 - ssim_metric: 0.8440 - val_loss: 0.0077 - val_psnr_metric: 21.8070 - val_ssim_metric: 0.7899
# Epoch 115/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0043 - psnr_metric: 24.2585 - ssim_metric: 0.8398 - val_loss: 0.0076 - val_psnr_metric: 21.8371 - val_ssim_metric: 0.8040
# Epoch 116/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0043 - psnr_metric: 24.2822 - ssim_metric: 0.8462 - val_loss: 0.0075 - val_psnr_metric: 21.9097 - val_ssim_metric: 0.7845
# Epoch 117/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0042 - psnr_metric: 24.3315 - ssim_metric: 0.8441 - val_loss: 0.0073 - val_psnr_metric: 22.0869 - val_ssim_metric: 0.8004
# Epoch 118/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0042 - psnr_metric: 24.3544 - ssim_metric: 0.8448 - val_loss: 0.0074 - val_psnr_metric: 22.0056 - val_ssim_metric: 0.7567
# Epoch 119/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0042 - psnr_metric: 24.3842 - ssim_metric: 0.8421 - val_loss: 0.0073 - val_psnr_metric: 22.0527 - val_ssim_metric: 0.7785
# Epoch 120/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0042 - psnr_metric: 24.3718 - ssim_metric: 0.8451 - val_loss: 0.0075 - val_psnr_metric: 21.9836 - val_ssim_metric: 0.8089
# Epoch 121/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0042 - psnr_metric: 24.3864 - ssim_metric: 0.8501 - val_loss: 0.0073 - val_psnr_metric: 22.0283 - val_ssim_metric: 0.8108
# Epoch 122/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0042 - psnr_metric: 24.3579 - ssim_metric: 0.8478 - val_loss: 0.0076 - val_psnr_metric: 21.8938 - val_ssim_metric: 0.7992
# Epoch 123/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.4319 - ssim_metric: 0.8502 - val_loss: 0.0074 - val_psnr_metric: 22.0576 - val_ssim_metric: 0.7779
# Epoch 124/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0042 - psnr_metric: 24.4180 - ssim_metric: 0.8482 - val_loss: 0.0075 - val_psnr_metric: 21.9555 - val_ssim_metric: 0.8039
# Epoch 125/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.4426 - ssim_metric: 0.8507 - val_loss: 0.0073 - val_psnr_metric: 22.0422 - val_ssim_metric: 0.7679
# Epoch 126/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0042 - psnr_metric: 24.3989 - ssim_metric: 0.8498 - val_loss: 0.0074 - val_psnr_metric: 22.0354 - val_ssim_metric: 0.7929
# Epoch 127/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.4841 - ssim_metric: 0.8496 - val_loss: 0.0074 - val_psnr_metric: 22.0349 - val_ssim_metric: 0.8019
# Epoch 128/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.4314 - ssim_metric: 0.8491 - val_loss: 0.0076 - val_psnr_metric: 21.8927 - val_ssim_metric: 0.7941
# Epoch 129/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.4643 - ssim_metric: 0.8508 - val_loss: 0.0071 - val_psnr_metric: 22.1435 - val_ssim_metric: 0.8115
# Epoch 130/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.4995 - ssim_metric: 0.8537 - val_loss: 0.0072 - val_psnr_metric: 22.1585 - val_ssim_metric: 0.8115
# Epoch 131/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0041 - psnr_metric: 24.5127 - ssim_metric: 0.8534 - val_loss: 0.0074 - val_psnr_metric: 22.0006 - val_ssim_metric: 0.8045
# Epoch 132/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0041 - psnr_metric: 24.5282 - ssim_metric: 0.8537 - val_loss: 0.0074 - val_psnr_metric: 22.0308 - val_ssim_metric: 0.7895
# Epoch 133/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.5376 - ssim_metric: 0.8522 - val_loss: 0.0073 - val_psnr_metric: 22.0298 - val_ssim_metric: 0.7342
# Epoch 134/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.5358 - ssim_metric: 0.8484 - val_loss: 0.0073 - val_psnr_metric: 22.0637 - val_ssim_metric: 0.7740
# Epoch 135/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.6030 - ssim_metric: 0.8518 - val_loss: 0.0070 - val_psnr_metric: 22.2262 - val_ssim_metric: 0.7926
# Epoch 136/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.6156 - ssim_metric: 0.8551 - val_loss: 0.0071 - val_psnr_metric: 22.2367 - val_ssim_metric: 0.8121
# Epoch 137/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.6304 - ssim_metric: 0.8544 - val_loss: 0.0071 - val_psnr_metric: 22.2383 - val_ssim_metric: 0.7948
# Epoch 138/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.6354 - ssim_metric: 0.8564 - val_loss: 0.0075 - val_psnr_metric: 21.9517 - val_ssim_metric: 0.8128
# Epoch 139/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0040 - psnr_metric: 24.5847 - ssim_metric: 0.8569 - val_loss: 0.0073 - val_psnr_metric: 22.1075 - val_ssim_metric: 0.8113
# Epoch 140/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0040 - psnr_metric: 24.6180 - ssim_metric: 0.8548 - val_loss: 0.0072 - val_psnr_metric: 22.0835 - val_ssim_metric: 0.7215
# Epoch 141/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.6505 - ssim_metric: 0.8496 - val_loss: 0.0072 - val_psnr_metric: 22.1236 - val_ssim_metric: 0.7297
# Epoch 142/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0040 - psnr_metric: 24.6011 - ssim_metric: 0.8514 - val_loss: 0.0071 - val_psnr_metric: 22.2190 - val_ssim_metric: 0.8153
# Epoch 143/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.6378 - ssim_metric: 0.8536 - val_loss: 0.0071 - val_psnr_metric: 22.1673 - val_ssim_metric: 0.8174
# Epoch 144/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.7473 - ssim_metric: 0.8598 - val_loss: 0.0071 - val_psnr_metric: 22.1712 - val_ssim_metric: 0.7511
# Epoch 145/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.7291 - ssim_metric: 0.8579 - val_loss: 0.0071 - val_psnr_metric: 22.1791 - val_ssim_metric: 0.8126
# Epoch 146/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.6989 - ssim_metric: 0.8585 - val_loss: 0.0072 - val_psnr_metric: 22.1519 - val_ssim_metric: 0.7941
# Epoch 147/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.7094 - ssim_metric: 0.8593 - val_loss: 0.0071 - val_psnr_metric: 22.2011 - val_ssim_metric: 0.8086
# Epoch 148/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0039 - psnr_metric: 24.7207 - ssim_metric: 0.8566 - val_loss: 0.0071 - val_psnr_metric: 22.1809 - val_ssim_metric: 0.8175
# Epoch 149/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.7444 - ssim_metric: 0.8596 - val_loss: 0.0071 - val_psnr_metric: 22.2368 - val_ssim_metric: 0.8179
# Epoch 150/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.7659 - ssim_metric: 0.8596 - val_loss: 0.0069 - val_psnr_metric: 22.3696 - val_ssim_metric: 0.8204
# Epoch 151/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.7777 - ssim_metric: 0.8587 - val_loss: 0.0073 - val_psnr_metric: 22.0684 - val_ssim_metric: 0.8003
# Epoch 152/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.8159 - ssim_metric: 0.8585 - val_loss: 0.0074 - val_psnr_metric: 22.0196 - val_ssim_metric: 0.8025
# Epoch 153/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0038 - psnr_metric: 24.7897 - ssim_metric: 0.8550 - val_loss: 0.0071 - val_psnr_metric: 22.2076 - val_ssim_metric: 0.8186
# Epoch 154/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0038 - psnr_metric: 24.8472 - ssim_metric: 0.8594 - val_loss: 0.0070 - val_psnr_metric: 22.2490 - val_ssim_metric: 0.7908
# Epoch 155/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0038 - psnr_metric: 24.8005 - ssim_metric: 0.8612 - val_loss: 0.0070 - val_psnr_metric: 22.2281 - val_ssim_metric: 0.8209
# Epoch 156/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.8060 - ssim_metric: 0.8636 - val_loss: 0.0070 - val_psnr_metric: 22.2665 - val_ssim_metric: 0.8040
# Epoch 157/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.8378 - ssim_metric: 0.8627 - val_loss: 0.0072 - val_psnr_metric: 22.1341 - val_ssim_metric: 0.8107
# Epoch 158/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.8125 - ssim_metric: 0.8594 - val_loss: 0.0069 - val_psnr_metric: 22.3001 - val_ssim_metric: 0.7786
# Epoch 159/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0037 - psnr_metric: 24.8608 - ssim_metric: 0.8587 - val_loss: 0.0072 - val_psnr_metric: 22.1283 - val_ssim_metric: 0.8052
# Epoch 160/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0037 - psnr_metric: 24.8641 - ssim_metric: 0.8591 - val_loss: 0.0070 - val_psnr_metric: 22.2835 - val_ssim_metric: 0.8176
# Epoch 161/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0037 - psnr_metric: 24.8682 - ssim_metric: 0.8622 - val_loss: 0.0068 - val_psnr_metric: 22.4224 - val_ssim_metric: 0.8173
# Epoch 162/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0038 - psnr_metric: 24.8456 - ssim_metric: 0.8612 - val_loss: 0.0070 - val_psnr_metric: 22.2936 - val_ssim_metric: 0.8192
# Epoch 163/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0037 - psnr_metric: 24.9317 - ssim_metric: 0.8647 - val_loss: 0.0070 - val_psnr_metric: 22.2892 - val_ssim_metric: 0.8134
# Epoch 164/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0037 - psnr_metric: 24.9457 - ssim_metric: 0.8637 - val_loss: 0.0071 - val_psnr_metric: 22.2454 - val_ssim_metric: 0.8161
# Epoch 165/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0037 - psnr_metric: 24.9595 - ssim_metric: 0.8612 - val_loss: 0.0069 - val_psnr_metric: 22.3224 - val_ssim_metric: 0.8219
# Epoch 166/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0037 - psnr_metric: 24.9273 - ssim_metric: 0.8623 - val_loss: 0.0072 - val_psnr_metric: 22.1601 - val_ssim_metric: 0.8126
# Epoch 167/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0037 - psnr_metric: 24.9557 - ssim_metric: 0.8628 - val_loss: 0.0069 - val_psnr_metric: 22.3273 - val_ssim_metric: 0.8055
# Epoch 168/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0036 - psnr_metric: 24.9811 - ssim_metric: 0.8637 - val_loss: 0.0070 - val_psnr_metric: 22.2407 - val_ssim_metric: 0.8028
# Epoch 169/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 27s 23ms/step - loss: 0.0035 - psnr_metric: 25.1347 - ssim_metric: 0.8685 - val_loss: 0.0068 - val_psnr_metric: 22.3742 - val_ssim_metric: 0.8271
# Epoch 190/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0035 - psnr_metric: 25.1838 - ssim_metric: 0.8681 - val_loss: 0.0068 - val_psnr_metric: 22.4391 - val_ssim_metric: 0.8275
# Epoch 191/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0035 - psnr_metric: 25.1506 - ssim_metric: 0.8695 - val_loss: 0.0066 - val_psnr_metric: 22.5162 - val_ssim_metric: 0.8280
# Epoch 192/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0035 - psnr_metric: 25.1838 - ssim_metric: 0.8724 - val_loss: 0.0078 - val_psnr_metric: 21.8115 - val_ssim_metric: 0.7938
# Epoch 193/300
# 1188/1188 ━━━━━━━━━━━━━━━━━━━━ 28s 23ms/step - loss: 0.0034 - psnr_metric: 25.2138 - ssim_metric: 0.8688 - val_loss: 0.0068 - val_psnr_metric: 22.3946 - val_ssim_metric: 0.8276
# Epoch 194/300
#  880/1188 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0034 - psnr_metric: 25.3260 - ssim_metric: 0.8685

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'psnr_metric', 'ssim_metric', 'val_loss', 'val_psnr_metric', 'val_ssim_metric'])

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['ssim_metric'], label='Training SSIM')
plt.plot(history.history['val_ssim_metric'], label='Test SSIM')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test SSIM')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['psnr_metric'], label='Training PSNR')
plt.plot(history.history['val_psnr_metric'], label='Test PSNR')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs test PSNR')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Evaluation by Plotting Images

# %%
import matplotlib.pyplot as plt

i = 50# index of sample
pred = model.predict(x_train[i:i+1])[0]

plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(x_train[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(y_train[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(pred.squeeze(), cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step

# %%
import matplotlib.pyplot as plt

i = 200# index of sample
pred = model.predict(x_test[i:i+1])[0]

plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(x_test[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("Ground Truth")
plt.imshow(y_test[i].squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Prediction")
plt.imshow(pred.squeeze(), cmap='gray')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %% [markdown]
# ## Evaluate using PSNR and SSIM

# %%
import tensorflow as tf
import numpy as np

total_psnr = 0.0
total_ssim = 0.0
n = len(x_test)

for i in range(n):
    pred = model.predict(x_test[i:i+1], verbose=0)  # shape: (1, 256, 256, 1)
    gt = y_test[i:i+1]

    # Compute PSNR and SSIM
    psnr_val = tf.image.psnr(gt, pred, max_val=1.0).numpy()[0]
    ssim_val = tf.image.ssim(gt, pred, max_val=1.0).numpy()[0]

    total_psnr += psnr_val
    total_ssim += ssim_val

# Average metrics
avg_psnr = total_psnr / n
avg_ssim = total_ssim / n

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average SSIM: {avg_ssim:.4f}")

# %%
import tensorflow as tf
import numpy as np

total_psnr = 0.0
total_ssim = 0.0
n = len(x_test)

for i in range(n):
    pred = model.predict(x_train[i:i+1], verbose=0)  # shape: (1, 256, 256, 1)
    gt = y_train[i:i+1]

    # Compute PSNR and SSIM
    psnr_val = tf.image.psnr(gt, pred, max_val=1.0).numpy()[0]
    ssim_val = tf.image.ssim(gt, pred, max_val=1.0).numpy()[0]

    total_psnr += psnr_val
    total_ssim += ssim_val

# Average metrics
avg_psnr = total_psnr / n
avg_ssim = total_ssim / n

print(f"Average PSNR: {avg_psnr:.2f} dB")
print(f"Average SSIM: {avg_ssim:.4f}")

# %%
model.save('automap_v4_dense_300.h5')
